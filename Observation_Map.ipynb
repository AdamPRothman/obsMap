# %% [markdown]
# CNFAIC Observation Map
# Goal:
# Make a map of recent (<7 days) observations.
#
# Ideas:
# - Custom date range
# - Icons based on dates
# - Professional only mode
#
# Steps:
# - Load observations and relevant data
# - Assign location to observation
# - Map observation
#     - Format tags and popups
#
# To Do:
# - Make popups nice
#     - Add border, for slides only?
#     - Add icon for slide
# - Add wx with different markers
# - Create website with legend around map
# - Layer options and menu clean-up
#
# Low Priority:
# - Fix encoding in notebook
# - Fix flag count. There will be issues if other tables or length of avalanch table has additional rows

# %%
#Load libraries
import base64
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
import folium
from folium import IFrame
import folium.plugins as plugins
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import datetime

# %%
#Observation dataframe
Obs = pd.DataFrame(columns = ('Location', 'Date', 'Observer','Lat','Lon'))
Obs

#read observation archive

obsArchive = pd.read_pickle('./obsArchive.pkl')

# %%
def getObs(url):
    #Open url and convert to soup
    html = urlopen(url).read()
    soup = BeautifulSoup(html)
    with open('./Observations/'+ url[36:-1], 'a') as file: file.write(str(soup))
    
    #Pull location
    location = str(soup.find('title'))
    #location = location.replace("[\\u2018\\u2019]", "'") #Replace curly single quote with straight
    location = location[7:location.find('|') - 1]
    
    #Pull observer info, first check for anonymous report
    if str(soup.select_one(
        'div[ class *= cnfaic_obs-table-browse-observations-byline]')) \
        == '<div class="cnfaic_obs-table-browse-observations-byline">Anonymous</div>':
        observer = 'Anonymous'
    else:
        observer = soup.select_one("span[class *= cnfaic_obs-table-browse-observations-byline]").text
        observer = observer[:-1]
        
    #Pull date
    date = soup.select('div[ class *= "top_meta"]')
    date = date[1].text
    formattedDate = formatTime(date)
    
    #Pull coordinates
    if len(soup.find_all("a", href=lambda href: href and "google" in href)) > 0:
        links = soup.find_all("a", href=lambda href: href and "google" in href)
        coords = str(links[0])
        coords = coords[coords.find('q='):coords.find("'>")]
        lat = float(coords[coords.find('=') + 1 : coords.find(',') - 1])
        lon = float(coords[coords.find(",") + 1 : coords.find('target') - 2])
    else:
        lat = float('NaN')
        lon = float('NaN')
        
    #Red Flags
    if soup.find_all('tr') != []:
        table = soup.find_all('tr')
        
    
        rows = soup.find_all('tr')
        flags = []
        if len(rows) == 4: #Check for avalanche table, if avy table is there length is 7
            for row in rows:
                cols = row.find_all('td')
                cols = [ele.text.strip() for ele in cols]
                flags.append([ele for ele in cols if ele]) 
        else: #if avy table is above red flag table then this will work, assuming there isn't a table below it
            rows = rows[-3:]
            for row in rows:
                cols = row.find_all('td')
                cols = [ele.text.strip() for ele in cols]
                flags.append([ele for ele in cols if ele]) 
                
        recentAvy = flags[0][1] == 'Yes'
        collapsing = flags[1][1] == 'Yes'
        cracking = flags[2][1] == 'Yes'
    else:
        recentAvy = False
        collapsing = False
        cracking = False
    
    flagCount = 0
    if recentAvy == True:
        flagCount += 1
    if collapsing == True:
        flagCount += 1
    if cracking == True:
        flagCount += 1
        
    
    #Create dataframe from data
    d = {'Date':[formattedDate],'Location':[location], 'Observer':[observer],'Lat':[lat], 
         'Lon': [lon], 'Recent Avy':[recentAvy], 'Collapsing' : [collapsing], 
         'Cracking' : [cracking], 'flagCount' : flagCount, 'url' : [url]}
    oneObs = pd.DataFrame(data = d)
    
    #Pull red flags

    return(oneObs)

# %%
def getUrls():
    url = 'https://www.cnfaic.org/view-observations/'
    html = urlopen(url).read()
    soup = BeautifulSoup(html)
    table = soup.find('table')
    links = table.find_all('a')
    urls = list()
    gallery = 'gallery'
    i = 0
    for link in range(len(links)):
        if gallery in str(links[link]):
            i = i
        else:
            url = str(links[link])
            url = url[ 9 : url.find('>') - 1]
            if (obsArchive['url'] == url).any():
                i = i
            else:
                urls.append(url)
                i += 1
    return(urls)

# %%
def getNewObs():
    newObs = pd.DataFrame()
    urls = getUrls()
    for i in range(len(urls)):  #Changed this
        newObs = newObs.append(getObs(urls[i]))
    
    newObs.reset_index(inplace = True, drop = True)
    newObs['url'] = urls
    return(newObs)

# %%
def addNewObs(obsArchive):
    newObs = getNewObs()

    for i in range(len(newObs)):
        obsArchive = obsArchive.append(newObs.iloc[i])       
        #Save the soup to the observations folder
        #with open('./Observations/'+ url[36:-1], 'a') as file: file.write(str(soup))
            
    obsArchive = obsArchive.sort_values('Date', ascending = False)    
    obsArchive.reset_index(inplace = True, drop = True)

    obsArchive.to_pickle('./obsArchive.pkl')
    return(obsArchive)

# %%
def formatTime(dateString):

    i = 0
    calendar = {'Jan':'01', 'Feb':'02', 'Mar':'03', 'Apr':'04', 'May':'05', 'Jun':'06', 'Jul':'07',
               'Aug':'08', 'Sep':'09', 'Oct':'10', 'Nov':'11', 'Dec':'12'}
    month = calendar[dateString[0:3]]

    day = dateString[dateString.find(',')-2:dateString.find(',')]
    if day[0] == ' ':
        day = '0' + day[1]

    year = dateString[dateString.find(',')+2:dateString.find(',')+6]
    year
    if dateString[-1] == 'm':
        time = dateString[-7:]
        if time[0] == ' ':
            time = '0' + time[1:]
    else:
        time = dateString[-5:]
        if time[0] == ' ':
            time = '0' + time[1:]

    dateString = str(year) + '-' + str(month) + '-' + str(day) + ' ' + time
    try:
        datetime.datetime.strptime(dateString, '%Y-%m-%d %H:%M%p')
    except:
        date = datetime.datetime.strptime(dateString, '%Y-%m-%d %H:%M')
    else:
        date = datetime.datetime.strptime(dateString, '%Y-%m-%d %H:%M%p')
    return(date)

# %%
obsArchive = addNewObs(obsArchive)
obsArchive
# Out:
#                    Date             Location  \
# 0   2020-12-17 08:44:00                 Orca
# 1   2020-12-17 04:01:00    Summit – Manitoba
# 2   2020-12-16 08:05:00               Magnum
# 3   2020-12-15 08:55:00  Thousand Dollar Run
# 4   2020-12-15 02:00:00             Sunburst
# ..                  ...                  ...
# 137 2020-11-12 08:09:00      Girdwood Valley
# 138 2020-11-11 02:00:00               Tincan
# 139 2020-11-10 12:00:00   Hiland Front Range
# 140 2020-11-10 06:23:00           Hatch peak
# 141 2020-11-09 10:43:00   Marmot Test Slopes
#
#                                   Observer        Lat         Lon Recent Avy  \
# 0    Schauer/ Pfeiffer/Wunnicke Forecaster  60.934343 -149.111090      False
# 1                             Caleb Rauch   60.684329 -149.418150      False
# 2      Johnston-Bloom / Roberts Forecaster  60.753490 -149.200954      False
# 3                      Rauch/Wright Kayes   61.767370 -149.298544      False
# 4                            Dylan Lenzie   60.794430 -149.199667      False
# ..                                     ...        ...         ...        ...
# 137                      George Creighton   60.995496 -149.093237      False
# 138                          Andy Moderow   60.785344 -149.164476       True
# 139                              Anonymous  61.216874 -149.467287      False
# 140                                   b s   61.766294 -149.305496      False
# 141                 Jed Workman Forecaster  61.782897 -149.268975       True
#
#     Collapsing Cracking  flagCount  \
# 0        False    False          0
# 1        False    False          0
# 2        False    False          0
# 3        False    False          0
# 4        False    False          0
# ..         ...      ...        ...
# 137       True    False          1
# 138       True    False          2
# 139      False    False          0
# 140      False    False          0
# 141       True     True          3
#
#                                                    url ageGroup
# 0          https://www.cnfaic.org/observations/orca-2/      NaN
# 1    https://www.cnfaic.org/observations/summit-man...      NaN
# 2       https://www.cnfaic.org/observations/magnum-55/      NaN
# 3    https://www.cnfaic.org/observations/thousand-d...     week
# 4    https://www.cnfaic.org/observations/sunburst-237/     week
# ..                                                 ...      ...
# 137  https://www.cnfaic.org/observations/girdwood-v...      old
# 138    https://www.cnfaic.org/observations/tincan-287/      old
# 139  https://www.cnfaic.org/observations/hiland-fro...      old
# 140  https://www.cnfaic.org/observations/hatch-peak...      old
# 141  https://www.cnfaic.org/observations/marmot-tes...      old
#
# [142 rows x 11 columns]

# %%
"""formattedDates = []
for i in range(len(obsArchive)):
    formattedDates.append(formatTime(obsArchive.iloc[i][0]))

obsArchive['Date'] = formattedDates
    """
# Out:
# "formattedDates = []\nfor i in range(len(obsArchive)):\n    formattedDates.append(formatTime(obsArchive.iloc[i][0]))\n\nobsArchive['Date'] = formattedDates\n    "

# %%
# Load USGS
url_base = 'http://server.arcgisonline.com/ArcGIS/rest/services/'
service = 'NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
tileset = url_base + service

# Create the map
m = folium.Map(location = [60.79443,-149.199667], zoom_start = 11, tiles = tileset,
               attr='USGS Style')


# Add markers to map
"""for i in range(len(obsArchive)):
    if str(obsArchive.iloc[i][3]) != 'nan':
        folium.Marker([obsArchive.iloc[i][3],obsArchive.iloc[i][4]], popup = 
                      obsArchive.iloc[i][1] + ' ' +
                      '<a href="%s" target="_blank">Link</a>' % obsArchive.iloc[i][8]).add_to(m)
    """
# Out:
# 'for i in range(len(obsArchive)):\n    if str(obsArchive.iloc[i][3]) != \'nan\':\n        folium.Marker([obsArchive.iloc[i][3],obsArchive.iloc[i][4]], popup = \n                      obsArchive.iloc[i][1] + \' \' +\n                      \'<a href="%s" target="_blank">Link</a>\' % obsArchive.iloc[i][8]).add_to(m)\n    '

# %%
#Filter obs archive into 3 groups based on age of obs
today = datetime.datetime.today()
oneDay = datetime.timedelta(days = 2)
threeDays = datetime.timedelta(days = 4)
oneWeek = datetime.timedelta(days = 8)
i = 0


for i in range(len(obsArchive)):
    if obsArchive.iloc[i][0].replace(hour = 0, minute = 0, second = 0) + oneDay > today:
        obsArchive['ageGroup'][i] = 'yesterday'
    elif obsArchive.iloc[i][0].replace(hour = 0, minute = 0, second = 0) + threeDays > today:
        obsArchive['ageGroup'][i] = '3 day'
    elif obsArchive.iloc[i][0].replace(hour = 0, minute = 0, second = 0) + oneWeek > today:
        obsArchive['ageGroup'][i] = 'week'
    else:
        obsArchive['ageGroup'][i] = 'old'


obsArchive
# Out:
#                    Date             Location  \
# 0   2020-12-17 08:44:00                 Orca
# 1   2020-12-17 04:01:00    Summit – Manitoba
# 2   2020-12-16 08:05:00               Magnum
# 3   2020-12-15 08:55:00  Thousand Dollar Run
# 4   2020-12-15 02:00:00             Sunburst
# ..                  ...                  ...
# 137 2020-11-12 08:09:00      Girdwood Valley
# 138 2020-11-11 02:00:00               Tincan
# 139 2020-11-10 12:00:00   Hiland Front Range
# 140 2020-11-10 06:23:00           Hatch peak
# 141 2020-11-09 10:43:00   Marmot Test Slopes
#
#                                   Observer        Lat         Lon Recent Avy  \
# 0    Schauer/ Pfeiffer/Wunnicke Forecaster  60.934343 -149.111090      False
# 1                             Caleb Rauch   60.684329 -149.418150      False
# 2      Johnston-Bloom / Roberts Forecaster  60.753490 -149.200954      False
# 3                      Rauch/Wright Kayes   61.767370 -149.298544      False
# 4                            Dylan Lenzie   60.794430 -149.199667      False
# ..                                     ...        ...         ...        ...
# 137                      George Creighton   60.995496 -149.093237      False
# 138                          Andy Moderow   60.785344 -149.164476       True
# 139                              Anonymous  61.216874 -149.467287      False
# 140                                   b s   61.766294 -149.305496      False
# 141                 Jed Workman Forecaster  61.782897 -149.268975       True
#
#     Collapsing Cracking  flagCount  \
# 0        False    False          0
# 1        False    False          0
# 2        False    False          0
# 3        False    False          0
# 4        False    False          0
# ..         ...      ...        ...
# 137       True    False          1
# 138       True    False          2
# 139      False    False          0
# 140      False    False          0
# 141       True     True          3
#
#                                                    url   ageGroup
# 0          https://www.cnfaic.org/observations/orca-2/  yesterday
# 1    https://www.cnfaic.org/observations/summit-man...  yesterday
# 2       https://www.cnfaic.org/observations/magnum-55/      3 day
# 3    https://www.cnfaic.org/observations/thousand-d...      3 day
# 4    https://www.cnfaic.org/observations/sunburst-237/      3 day
# ..                                                 ...        ...
# 137  https://www.cnfaic.org/observations/girdwood-v...        old
# 138    https://www.cnfaic.org/observations/tincan-287/        old
# 139  https://www.cnfaic.org/observations/hiland-fro...        old
# 140  https://www.cnfaic.org/observations/hatch-peak...        old
# 141  https://www.cnfaic.org/observations/marmot-tes...        old
#
# [142 rows x 11 columns]

# %%
dfYes = obsArchive[obsArchive['ageGroup'].isin(['yesterday'])]
df3day = obsArchive[obsArchive['ageGroup'].isin(['3 day'])]
dfWeek = obsArchive[obsArchive['ageGroup'].isin(['week'])]

# %%
# Load USGS
url_base = 'http://server.arcgisonline.com/ArcGIS/rest/services/'
service = 'NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
tileset = url_base + service

# Create the map
m = folium.Map(location = [60.79443,-149.199667], zoom_start = 11, tiles = tileset,
               attr='USGS Style')


# Add markers to map
"""for i in range(len(obsArchive)):
    if str(obsArchive.iloc[i][3]) != 'nan':
        folium.Marker([obsArchive.iloc[i][3],obsArchive.iloc[i][4]], popup = 
                      obsArchive.iloc[i][1] + ' ' +
                      '<a href="%s" target="_blank">Link</a>' % obsArchive.iloc[i][8]).add_to(m)
    """


fgObs = folium.FeatureGroup(name = 'Observations')
m.add_child(fgObs)
gYes = folium.plugins.FeatureGroupSubGroup(fgObs, 'Yesterday')
g3day = folium.plugins.FeatureGroupSubGroup(fgObs, '3 Days')
gWeek = folium.plugins.FeatureGroupSubGroup(fgObs, 'One Week')
subGroups = [gYes, g3day, gWeek]


frames = [dfYes, df3day, dfWeek]
colors = ['red', 'green', 'blue']
resolution, width, height = (72, 40, 40)

#iterate through the three time frames:
for i in range(len(frames)):
    m.add_child(subGroups[i])
    
    #iterate through the obs:
    for j in range(len(frames[i])):
        if str(frames[i].iloc[j][3]) != 'nan':  #only handle observations with coordinates
            filename = 'flag (' + str(int(frames[i].iloc[j][[8]])) + ').jpg' #load correct flag image
            encoded = base64.b64encode(open(filename, 'rb').read())
            image='<img src="data:image/jpeg;base64,{}">'.format 
            
            #create html for IFrame
            html = ('<b style="font-family:Helvetica,Arial,sans-serif; font-size: 16px;"> ' 
                    + '<a href="{}" target="_blank">{}</a>'.format(frames[i].iloc[j][9], frames[i].iloc[j][1])
                    + '</b> <br /> <body style="font-family:Helvetica,Arial,sans-serif; font-size: 14px;">'
                    + frames[i].iloc[j][2] + '<br />'
                    + frames[i].iloc[j][0].strftime("%m/%d/%Y, %H:%M %p") + '</body> <br>'
                    + image(encoded.decode('UTF-8')))
            #Create IFrame
            iframe = IFrame(html, width = 2000)
            popup = folium.Popup(iframe, min_width = 200, max_width = 2000)
            
            #add marker to subgroup
            subGroups[i].add_child(
                folium.Marker([frames[i].iloc[j][3],
                frames[i].iloc[j][4]], 
                popup = popup,
                icon = folium.Icon(color = colors[i])))

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
'<a href="{}" target="_blank">{}</a>'.format(frames[0].iloc[0][9], frames[0].iloc[0][1])
# Out:
# '<a href="https://www.cnfaic.org/observations/thousand-dollar-run-6/" target="_blank">Thousand Dollar Run</a>'

# %% [markdown]
# Working Zone

# %%
#Better Pop-ups
#Create new map to practice popups on:
# Load USGS
url_base = 'http://server.arcgisonline.com/ArcGIS/rest/services/'
service = 'NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
tileset = url_base + service

# Create the map
testMap = folium.Map(location = [60.79443,-149.199667], zoom_start = 11, tiles = tileset,
               attr='USGS Style')
i = 0
testFG = folium.FeatureGroup('popup test')
#Select images for the pop-up:
Filename ='flag (' + str(int(obsArchive.iloc[0][[8]])) + ').jpg'
encoded = base64.b64encode(open(Filename, 'rb').read())
image='<img src="data:image/jpeg;base64,{}">'.format 
#resolution, width, height = 72, 40, 40
"""iframe = IFrame(html(encoded.decode('UTF-8')), width=(width)+10, 
                height=(height)+10)
popup = folium.Popup(iframe, max_width=1000)
icon = folium.Icon(color="red", icon="ok")
marker = folium.Marker(location=[60.794430,	-149.199667], popup=popup, icon=icon)
marker.add_to(testMap)"""


testMap.add_child(folium.Marker([obsArchive.iloc[0][3],obsArchive.iloc[0][4]], 
                                popup = '<style> h1 {white-space: nowrap; font-size: 120%;}</style> <h1>' +
                                '<a href="%s" target="_blank">%s</a>' % (obsArchive.iloc[0][9], obsArchive.iloc[0][1]) +
                                '</h1>' +
                                obsArchive.iloc[0][2] + '<br>'+
                                obsArchive.iloc[0][0].strftime("%m/%d/%y %H:%M",) +
                                image(encoded.decode('UTF-8')) ,
                                icon = folium.Icon(color = colors[i])))

testMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Filename ='flag (' + str(int(obsArchive.iloc[0][[8]])) + ').jpg'
encoded = base64.b64encode(open(Filename, 'rb').read())
html='<img src="data:image/jpeg;base64,{}">'.format 
resolution, width, height = 72, 40, 40
iframe = IFrame(html(encoded.decode('UTF-8')), width=(width)+10, 
                height=(height)+10)
popup = folium.Popup( iframe,min_width = 500, max_width=1000)
icon = folium.Icon(color="red", icon="ok")
marker = folium.Marker(location=[60.794430,	-149.199667], popup=popup, icon=icon)
marker.add_to(testMap)

# %%
encoded = base64.b64encode(open('flag (' + str(obsArchive.iloc[0][8]) + ').jpg','rb').read())

# %%
testObs = getObs('https://www.cnfaic.org/observations/eddies-111/')

# %%
testMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
url_base = 'http://server.arcgisonline.com/ArcGIS/rest/services/'
service = 'NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
tileset = url_base + service

# Create the map
testMap = folium.Map(location = [60.79443,-149.199667], zoom_start = 11, tiles = tileset,
               attr='USGS Style')

popup = folium.Popup(testObs.iloc[0][1])
marker = folium.Marker(location = [60.794430, -149.118785], popup = popup, icon = folium.Icon(color = 'red'))
marker.add_to(testMap)
testMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
getObs('https://www.cnfaic.org/observations/eddies-111/')
# Out:
#                  Date Location            Observer        Lat         Lon  \
# 0 2020-12-12 08:31:00  Eddie’s  Kakiko Ramos-Leon   60.799749 -149.118785
#
#    Recent Avy  Collapsing  Cracking  flagCount  \
# 0        True       False     False          1
#
#                                                url
# 0  https://www.cnfaic.org/observations/eddies-111/

# %%
url = 'https://www.cnfaic.org/observations/raggedtop-17/'
html = urlopen(url).read()
soup = BeautifulSoup(html)

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html><head>
# <title>Raggedtop | Chugach Avalanche Center </title>
# <meta content="width=device-width" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" rel="stylesheet"/>
# <link href="https://www.cnfaic.org/wp-content/themes/cnfaic/style.css?v=020120" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//www.avantlink.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://www.cnfaic.org/wp-content/plugins/instagram-feed-pro/css/sbi-styles.min.css?ver=5.8" id="sbi_styles-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.cnfaic.org/wp-content/plugins/the-events-calendar/common/src/resources/css/common-skeleton.min.css?ver=4.12.15" id="tribe-common-skeleton-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.cnfaic.org/wp-content/plugins/the-events-calendar/common/src/resources/css/tooltip.min.css?ver=4.12.15" id="tribe-tooltip-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.cnfaic.org/wp-includes/css/dist/block-library/style.min.css?ver=5.6" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.cnfaic.org/wp-content/plugins/akavalanche/advisory.css?v=021020&amp;ver=092220" id="style1-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.cnfaic.org/wp-content/plugins/avantlink-wp/css/rp_style.css?ver=5.6" id="avantlink_rp_style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.cnfaic.org/wp-content/plugins/avantlink-wp/css/ps_style.css?ver=5.6" id="avantlink_ps_style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.cnfaic.org/wp-includes/css/dashicons.min.css?ver=5.6" id="dashicons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.cnfaic.org/wp-content/plugins/cnfaic_obs/css/style.css?ver=020220" id="cnfaic_obs-styles-css" media="" rel="stylesheet" type="text/css"/>
# <script id="jquery-core-js" src="https://www.cnfaic.org/wp-includes/js/jquery/jquery.min.js?ver=3.5.1" type="text/javascript"></script>
# <script id="jquery-migrate-js" src="https://www.cnfaic.org/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.3.2" type="text/javascript"></script>
# <link href="https://www.cnfaic.org/observations/raggedtop-17/" rel="canonical"/>
# <!-- BEGIN ExactMetrics v5.3.9 Universal Analytics - https://exactmetrics.com/ -->
# <script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-22476190-1', 'auto');
#   ga('send', 'pageview');
# </script>
# <!-- END ExactMetrics Universal Analytics -->
# <script crossorigin="anonymous" integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl" src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"></script>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# </head>
# <body class="observations-template-default single single-observations postid-26467 tribe-no-js">
# <div class="top-header">
# <ul class="top-header-menu">
# <li class="top-header-li"><a href="https://www.cnfaic.org/search/"><span class="dashicons dashicons-search"></span><span class="top-header-text">Search</span></a></li>
# <li class="top-header-li"><a href="https://www.cnfaic.org/about/contact/"><span class="dashicons dashicons-email"></span><span class="top-header-text">Contact</span></a></li>
# <li class="top-header-li"><a href="https://www.cnfaic.org/events/list/"><span class="dashicons dashicons-calendar-alt"></span><span class="top-header-text">Events</span></a></li>
# <li class="top-header-li"><a href="https://www.facebook.com/FCNFAIC/" target="_blank"><span class="dashicons dashicons-facebook"></span><span class="top-header-text">Facebook</span></a></li>
# <li class="top-header-li"><a href="https://www.instagram.com/chugachavy/" target="_blank"><span class="dashicons dashicons-instagram"></span><span class="top-header-text">Instagram</span></a></li>
# </ul>
# </div>
# <nav class="navbar navbar-expand-lg bg-faded">
# <a class="navbar-brand" href="https://www.cnfaic.org"><img alt="Chugach Avalanche Center" class="img-fluid" src="https://www.cnfaic.org/wp-content/themes/cnfaic/images/logo_combined.png"/></a>
# <a class="navbar-brand-mobile" href="https://www.cnfaic.org"><img alt="Chugach Avalanche Center" class="img-fluid" src="https://www.cnfaic.org/wp-content/themes/cnfaic/images/logo.png"/></a>
# <button aria-controls="navbarSupportedContent22" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler menu-button" data-target="#bs4navbar" data-toggle="collapse" type="button">
# <div class="animated-icon3"><span></span><span></span><span></span></div>
# </button>
# <div class="collapse navbar-collapse" id="bs4navbar"><ul class="navbar-nav ml-auto" id="menu-mobile-menu"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-20861 dropdown" id="menu-item-20861" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" title="Forecast">Forecast <span class="caret"></span></a>
# <ul class="dropdown-menu dropdown-menu-right" role="menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-20863" id="menu-item-20863" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/forecast/turnagain/" title="Latest Turnagain Forecast">Latest Turnagain Forecast</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-20864" id="menu-item-20864" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/forecast/turnagain/archives/" title="Turnagain Archives">Turnagain Archives</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-21812" id="menu-item-21812" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/forecast-hatcher/" title="Hatcher Pass Forecast">Hatcher Pass Forecast</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-20860 dropdown" id="menu-item-20860" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" title="Observations">Observations <span class="caret"></span></a>
# <ul class="dropdown-menu dropdown-menu-right" role="menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20899" id="menu-item-20899" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/view-observations/submit-observation/" title="Submit Observation">Submit Observation</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20865" id="menu-item-20865" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/view-observations/" title="All Observations">All Observations</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-20867" id="menu-item-20867" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/view-observations/?avalanche=1" title="Avalanches">Avalanches</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20858" id="menu-item-20858" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/view-accidents/" title="Accidents">Accidents</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-20872 dropdown" id="menu-item-20872" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" title="Weather">Weather <span class="caret"></span></a>
# <ul class="dropdown-menu dropdown-menu-right" role="menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-21450" id="menu-item-21450" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/wx/weather.php" title="Current Weather">Current Weather</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-21458" id="menu-item-21458" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/wx/wxmap.php" title="Weather Station Map">Weather Station Map</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-21527" id="menu-item-21527" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/weather/weather-history/" title="Weather History">Weather History</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-21451" id="menu-item-21451" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/wx/wx_site.php?site=seattle" title="Seattle Ridge">Seattle Ridge</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-21449" id="menu-item-21449" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/wx/wx_site.php?site=sunburst" title="Sunburst">Sunburst</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-21452" id="menu-item-21452" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/wx/wx_site.php?site=sn190" title="Sterling Hwy MP 37">Sterling Hwy MP 37</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-21453" id="menu-item-21453" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/wx/wx_site.php?site=sn191" title="Summit Lake MP 45">Summit Lake MP 45</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-21454" id="menu-item-21454" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/wx/wx_site.php?site=lostLake" title="Lost Lake">Lost Lake</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-21448" id="menu-item-21448" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/wx/wx_site.php?site=marmot" title="Marmot Wx">Marmot Wx</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-21455" id="menu-item-21455" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/wx/wx_site.php?site=arctic_valley" title="Arctic Valley">Arctic Valley</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-21456" id="menu-item-21456" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/wx/wx_site.php?site=penguin_peak" title="Penguin">Penguin</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-21457" id="menu-item-21457" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/wx/wx_site.php?site=anc_hillside" title="Glen Alps">Glen Alps</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-21459" id="menu-item-21459" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="http://www.data.beadedstream.com/projects/CNFAIC_TinCan_2015/tacdata.php?webid=58ZUXRDZXJZYKUPLS6DP&amp;units=C&amp;tz=" title="Tincan Snow Profile">Tincan Snow Profile</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-20868 dropdown" id="menu-item-20868" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" title="About">About <span class="caret"></span></a>
# <ul class="dropdown-menu dropdown-menu-right" role="menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20915" id="menu-item-20915" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/about/" title="About">About</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20875" id="menu-item-20875" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/about/resources/" title="Resources">Resources</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-21326" id="menu-item-21326" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/about/contact-us/" title="Contact Us">Contact Us</a></li>
# </ul>
# </li>
# <li class="last menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-20919 dropdown" id="menu-item-20919" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" title="Friends">Friends <span class="caret"></span></a>
# <ul class="dropdown-menu dropdown-menu-right" role="menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20869" id="menu-item-20869" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/friends/" title="Friends of the CNFAIC">Friends of the CNFAIC</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-21367" id="menu-item-21367" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/friends/sponsors-members/" title="Sponsors &amp; Members">Sponsors &amp; Members</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-21369" id="menu-item-21369" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/friends/sponsor-donation/" title="Become a Sponsor">Become a Sponsor</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20918" id="menu-item-20918" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/friends/scholarships/" title="Scholarships">Scholarships</a></li>
# </ul>
# </li>
# <li class="obs-button menu-item menu-item-type-post_type menu-item-object-page menu-item-21304" id="menu-item-21304" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/view-observations/submit-observation/" title="Observation">Observation</a></li>
# <li class="callout-button menu-item menu-item-type-post_type menu-item-object-page menu-item-20871" id="menu-item-20871" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement"><a href="https://www.cnfaic.org/friends/donate/" title="Donate">Donate</a></li>
# </ul></div></nav>
# <div class="content-wrap">
# <div class="container-fluid">
# <div class="row no-gutters">
# <div class="col-md-2 sidebar">
# <div class="sidebar_inner">
# <ul class="cnfaic_sidenav">
# <li><a href="https://www.cnfaic.org/view-observations/submit-observation/">Submit Observation</a></li>
# <li><a href="https://www.cnfaic.org/view-observations/">Observations</a></li>
# <li class="blue-underline"><a href="https://www.cnfaic.org/view-observations/?avalanche=1">Avalanches</a></li>
# <li><a href="https://www.cnfaic.org/view-accidents">Accidents</a></li>
# <li><a href="https://avalanche.org/avalanche-accidents/" target="_blank">U.S. Accidents</a>
# </li></ul>
# <div class="sponsorwrap">
# <div align="left" class="sponsor">
# <a href="http://www.conocophillipsalaska.com" target="_blank"><img alt="ConocoPhillips" src="https://www.cnfaic.org/files/img/sponsor/sponsor_cp.png"/></a></div>
# </div>
# </div>
# </div>
# <div class="col-md-10">
# <div class="cnfaic_obs-content-fields cnfaic_obs-content-fields-display"> <h1>Avalanche: <span class="cnfaic_obs-table-browse-observations-region"><span class="cnfaic_obs-terms-list cnfaic_obs-terms-list-regions"><span class="cnfaic_obs-terms-list-item cnfaic_obs-terms-list-item-regions">Girdwood</span></span></span> </h1> <h2>Location: <span class="cnfaic_obs-table-browse-observations-location">Raggedtop</span> </h2> <div class="row"><div class="col-md-4"><div class="top_meta_title">Date:</div> <div class="top_meta"><time datetime="December 12, 2020 7:05pm">December 12, 2020 7:05pm</time></div></div><div class="col-md-4"><div class="top_meta_title">Observer:</div> <div class="top_meta"><span class="cnfaic_obs-table-browse-observations-byline cnfaic_obs-table-browse-observations-byline-staff">Andrew Schauer /Alex Davis <span class="cnfaic_obs-staff">Forecaster</span> </span></div></div></div><div class="cnfaic_obs-route"><div class="cnfaic_obs-route-title cnfaic_obs-headerbar"><div class="cnfaic_obs-header">Route &amp; General Observations</div></div> <div class="cnfaic_obs-route-content"><p>We toured up to about 2800′ and skied in some small trees for better vis and less wind. The winds picked up throughout the day, and fresh wind slabs were reactive all day.</p>
# </div></div>
# <div class="cnfaic_obs-content-fieldset cnfaic_obs-content-fieldset-avalanche_details" id="cnfaic_obs-content-fieldset-avalanche_details">
# <div class="cnfaic_obs-content-fieldset-title cnfaic_obs-headerbar cnfaic_obs-headerbarwrap-avalanche_details">
# <div class="cnfaic_obs-header">Avalanche Details</div>
# <div class="cnfaic_obs-infotop">If this is an avalanche observation, click yes below and fill in the form as best as you can.  If people were involved, please
# 				provide details.  </div>
# </div>
# <div class="cnfaic_obs-content-fieldset-body cnfaic_obs-content-fieldset_avalanche_details-body">
# <div class="cnfaic_obs-content-field cnfaic_obs">
# <div class="cnfaic_obs-content-field-title cnfaic_obs-"></div>
# <div class="cnfaic_obs-content-field-body"><table class="table-striped cnfaic_obs-details_table"><tr><td class="cnfaic_obs-details_table-header">Trigger</td><td class="cnfaic_obs-details_table-cell"> Skier</td><td class="cnfaic_obs-details_table-header">Avalanche Type</td><td class="cnfaic_obs-details_table-cell"> Soft Slab</td></tr><tr><td class="cnfaic_obs-details_table-header">Aspect</td><td class="cnfaic_obs-details_table-cell"> North Northwest</td><td class="cnfaic_obs-details_table-header">Elevation</td><td class="cnfaic_obs-details_table-cell"> 2600ft</td></tr><tr><td class="cnfaic_obs-details_table-header">Slope Angle</td><td class="cnfaic_obs-details_table-cell">unknown</td><td class="cnfaic_obs-details_table-header">Crown Depth</td><td class="cnfaic_obs-details_table-cell"> 10in</td></tr><tr><td class="cnfaic_obs-details_table-header">Width</td><td class="cnfaic_obs-details_table-cell"> 25ft</td><td class="cnfaic_obs-details_table-header">Vertical Run</td><td class="cnfaic_obs-details_table-cell"> 25ft</td></tr></table></div>
# </div>
# <div class="cnfaic_obs-content-field cnfaic_obs">
# <div class="cnfaic_obs-content-field-title cnfaic_obs-AvalancheDetails">Avalanche Details</div>
# <div class="cnfaic_obs-content-field-body"><p>Skiers easily triggered small pockets of wind-loaded snow. The avalanches were not yet big enough to bury somebody.</p>
# </div>
# </div>
# <div class="cnfaic_obs_clear"></div></div>
# </div>
# <div class="cnfaic_obs-content-fieldset cnfaic_obs-content-fieldset-red_flags" id="cnfaic_obs-content-fieldset-red_flags">
# <div class="cnfaic_obs-content-fieldset-title cnfaic_obs-headerbar cnfaic_obs-headerbarwrap-red_flags">
# <div class="cnfaic_obs-header">Red Flags</div>
# <div class="cnfaic_obs-infotop">Red flags are simple visual clues that are a sign of potential avalanche danger. Please record any sign of red flags below.</div>
# </div>
# <div class="cnfaic_obs-content-fieldset-body cnfaic_obs-content-fieldset_red_flags-body">
# <div class="cnfaic_obs-content-field cnfaic_obs">
# <div class="cnfaic_obs-content-field-title cnfaic_obs-Obvioussignsofinstability">Obvious signs of instability</div>
# <div class="cnfaic_obs-content-field-body"><table class="table-striped cnfaic_obs-details_table"><tr><td class="cnfaic_obs-details_table-header">Recent Avalanches?</td><td class="cnfaic_obs-details_table-cell">Yes</td></tr><tr><td class="cnfaic_obs-details_table-header">Collapsing (Whumphing)?</td><td class="cnfaic_obs-details_table-cell">No</td></tr><tr><td class="cnfaic_obs-details_table-header">Cracking (Shooting cracks)?</td><td class="cnfaic_obs-details_table-cell">Yes</td></tr></table></div>
# </div>
# <div class="cnfaic_obs-content-field cnfaic_obs">
# <div class="cnfaic_obs-content-field-title cnfaic_obs-ObserverComments">Observer Comments</div>
# <div class="cnfaic_obs-content-field-body"><p>We easily triggered pockets of wind slabs. It was a little surprising to find them mid-slope and at the bottom of slopes too, in areas that would typically seem more sheltered. We also got a lot of shooting cracks in fresh wind slabs near the ridge.</p>
# </div>
# </div>
# <div class="cnfaic_obs_clear"></div></div>
# </div>
# <div class="cnfaic_obs-content-fieldset cnfaic_obs-content-fieldset-weather" id="cnfaic_obs-content-fieldset-weather">
# <div class="cnfaic_obs-content-fieldset-title cnfaic_obs-headerbar cnfaic_obs-headerbarwrap-weather">
# <div class="cnfaic_obs-header">Weather &amp; Snow Characteristics</div>
# <div class="cnfaic_obs-infotop">Please provide details to help us determine the weather and snowpack during the time this observation took place. </div>
# </div>
# <div class="cnfaic_obs-content-fieldset-body cnfaic_obs-content-fieldset_weather-body">
# <div class="cnfaic_obs-content-field cnfaic_obs">
# <div class="cnfaic_obs-content-field-title cnfaic_obs-Weather">Weather</div>
# <div class="cnfaic_obs-content-field-body"><p>Skies were cloudy, but we did get periods of good visibility. Light winds out of the south picked up to around 20 mph in the afternoon. We saw a lot of blowing snow off the ridge at higher elevations, and some slopes were completely scoured.</p>
# </div>
# </div>
# <div class="cnfaic_obs-content-field cnfaic_obs">
# <div class="cnfaic_obs-content-field-title cnfaic_obs-Snowsurface">Snow surface</div>
# <div class="cnfaic_obs-content-field-body"><p>Around a foot of soft snow made for good skiing, but there were pockets of stiffer wind-loaded snow. The fresh wind slabs were really touchy. We got a few small pockets to release, as well as some good shooting cracks near the ridge. Surface hoar still standing until we got above the alders. Above alder line it looks like it had blown away.</p>
# </div>
# </div>
# <div class="cnfaic_obs-content-field cnfaic_obs">
# <div class="cnfaic_obs-content-field-title cnfaic_obs-Snowpack">Snowpack</div>
# <div class="cnfaic_obs-content-field-body"><p>From a snowpit on a N aspect, 2450':<br/>
# 30 cm new snow on top of a firm crust. There is still a layer of facets in the bottom 5-10 cm snow at the ground, which produced mixed results in stability tests (ECTP25, ECTX).<br/>
# Fresh wind slabs were our primary concern, especially as winds picked up later in the day. The weak snow at the ground is an additional concern, especially in the steep, rocky terrain above where we dug, which would not have the same rain crust.</p>
# </div>
# </div>
# <div class="cnfaic_obs_clear"></div></div>
# </div>
# <div class="cnfaic_obs-content-fieldset cnfaic_obs-content-fieldset-photo_video" id="cnfaic_obs-content-fieldset-photo_video">
# <div class="cnfaic_obs-content-fieldset-title cnfaic_obs-headerbar cnfaic_obs-headerbarwrap-photo_video">
# <div class="cnfaic_obs-header">Photos &amp; Video</div>
# <div class="cnfaic_obs-infotop">Please upload photos below.  Maximum of 5 megabytes per image. <a href="https://www.wikihow.com/Resize-a-JPEG" target="_blank">Click here for help on resizing images.</a> If you are having trouble uploading please email images separately to staff.</div>
# </div>
# <div class="cnfaic_obs-content-fieldset-body cnfaic_obs-content-fieldset_photo_video-body">
# <div class="cnfaic_obs-content-field cnfaic_obs">
# <div class="cnfaic_obs-content-field-title cnfaic_obs-"></div>
# <div class="cnfaic_obs-content-field-body"><div class="cnfaic_obs-gallery">
# <a class="cnfaic_obs-gallery-link" href="https://www.cnfaic.org/wp-content/uploads/2020/12/IMG_3316-scaled.jpg" rel="gal" target="_blank" title="Shooting cracks in a fresh windslab near the ridge. Photo: Brooke Edwards 12.12.2020">
# <img class="cnfaic_obs-gallery-image" src="https://www.cnfaic.org/wp-content/uploads/2020/12/IMG_3316-768x1024.jpg"/>
# </a>
# <p class="cnfaic_obs-gallery-caption">Shooting cracks in a fresh windslab near the ridge. Photo: Brooke Edwards 12.12.2020  </p>
# <a class="cnfaic_obs-gallery-link" href="https://www.cnfaic.org/wp-content/uploads/2020/12/IMG_3315-scaled.jpg" rel="gal" target="_blank" title="More shooting cracks near the ridge. Photo: Brooke Edwards 12.12.2020">
# <img class="cnfaic_obs-gallery-image" src="https://www.cnfaic.org/wp-content/uploads/2020/12/IMG_3315-768x1024.jpg"/>
# </a>
# <p class="cnfaic_obs-gallery-caption">More shooting cracks near the ridge. Photo: Brooke Edwards 12.12.2020  </p>
# <a class="cnfaic_obs-gallery-link" href="https://www.cnfaic.org/wp-content/uploads/2020/12/Raggedtop_20201212.png" rel="gal" target="_blank" title="Snowpit on a N aspect at 2450'. Pointing at weak snow near the ground. 12.12.2020">
# <img class="cnfaic_obs-gallery-image" src="https://www.cnfaic.org/wp-content/uploads/2020/12/Raggedtop_20201212-1024x768.png"/>
# </a>
# <p class="cnfaic_obs-gallery-caption">Snowpit on a N aspect at 2450'. Pointing at weak snow near the ground. 12.12.2020  </p>
# </div></div>
# </div>
# <div class="cnfaic_obs_clear"></div></div>
# </div>
# <div class="cnfaic_obs-content-fieldset cnfaic_obs-content-fieldset-region_location" id="cnfaic_obs-content-fieldset-region_location">
# <div class="cnfaic_obs-content-fieldset-title cnfaic_obs-headerbar cnfaic_obs-headerbarwrap-region_location">
# <div class="cnfaic_obs-header">Location</div>
# <div class="cnfaic_obs-infotop"></div>
# </div>
# <div class="cnfaic_obs-content-fieldset-body cnfaic_obs-content-fieldset_region_location-body"><a class="cnfaic_obs-static-map-link" href="https://maps.google.com/maps?&amp;z=15&amp;mrt=yp&amp;t=k&amp;q=61.00945544059993,-149.10812857073978" target="_blank"><img class="cnfaic_obs-static-map" src="https://maps.googleapis.com/maps/api/staticmap?center=61.00945544059993%2C-149.10812857073978&amp;size=640x400&amp;zoom=11&amp;markers=61.00945544059993%2C-149.10812857073978&amp;maptype=terrain&amp;key=AIzaSyBOkRflqdovRqLNIuaxpz4QSZJtHymUnpk"/></a><div align="center"><small><em><a class="cnfaic_obs-static-map-link" href="https://maps.google.com/maps?&amp;z=15&amp;mrt=yp&amp;t=k&amp;q=61.00945544059993,-149.10812857073978" target="_blank">Click to Explore Location.</a></em></small></div> <div class="cnfaic_obs_clear"></div></div>
# </div>
# </div>
# </div><!-- / col -->
# </div><!-- / row -->
# </div><!-- /container-fluid -->
# </div><!-- / contentwrap -->
# <br/><br/>
# <div class="home_gray_footer">
# <div class="container-fluid">
# <div class="row no-gutters">
# <div class="col-md-6">
# <div class="home_image left-module" onclick="document.location='https://www.cnfaic.org/friends/donate/'" style="background-image: url('https://www.cnfaic.org/wp-content/themes/cnfaic/images/searcher_700.jpg');">
# <div class="image-gradient">
# <div class="home_image_title">Become a Member</div>
# <div class="home_image_text">If you think a public avalanche center is important please support our organization.</div>
# <div class="home_image_button_wrap">
# <div class="home_image_button"><a href="https://www.cnfaic.org/friends/donate/">Donate Now</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-6">
# <div class="home_image right-module" onclick="document.location='https://www.cnfaic.org/friends/shop/'" style="background-image: url('https://www.cnfaic.org/wp-content/themes/cnfaic/images/seattleridge_700.jpg');">
# <div class="image-gradient">
# <div class="home_image_title">Need new gear?</div>
# <div class="home_image_text">Make a purchase from our Affiliate Partners and CNFAIC will receive a portion of the sales. </div>
# <div class="home_image_button_wrap">
# <div class="home_image_button"><a href="https://www.cnfaic.org/friends/shop/">Shop Now</a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer class="footer footer_desktop">
# <div class="container">
# <div class="row">
# <div class="col-md-4">
# <a href="https://www.cnfaic.org"><img class="img-fluid" src="https://www.cnfaic.org/wp-content/themes/cnfaic/images/logo_combined.png"/></a>
# <div class="footer-sm">
# <a href="https://www.fs.usda.gov/detail/chugach/"><strong>In partnership with Chugach National Forest</strong></a> <br/>
# 		    Copyright © 2020 Chugach National Forest Avalanche Information Center. All rights reserved. </div>
# </div>
# <div class="col-md-2"></div>
# <div class="col-md-3">
# <h2>Contact Us</h2>
# 			P.O. Box 129 /<br/>
# 			145 Forest Station Road<br/>Girdwood, AK 99587<br/>
# <a href="https://www.cnfaic.org/about/contact"><span class="dashicons dashicons-email"></span>Contact Us</a>
# </div>
# <div class="col-md-3">
# <h2>Social</h2>
# <a href="https://www.cnfaic.org/events/list/"><span class="dashicons dashicons-calendar-alt"></span>Events</a><br/>
# <a href="https://www.facebook.com/FCNFAIC/" target="_blank"><span class="dashicons dashicons-facebook"></span>Facebook</a><br/>
# <a href="https://www.instagram.com/chugachavy/" target="_blank"><span class="dashicons dashicons-instagram"></span>Instagram</a>
# </div>
# </div>
# </div>
# </footer>
# <footer class="footer footer_mobile">
# <div class="container">
# <div class="row">
# <div align="center" class="col">
# <a href="https://www.cnfaic.org"><img class="img-fluid" src="https://www.cnfaic.org/wp-content/themes/cnfaic/images/logo_combined.png"/></a><br/>
# <a href="https://www.cnfaic.org/about/contact"><span class="dashicons dashicons-email"></span></a>
# <a href="https://www.cnfaic.org/events/list/"><span class="dashicons dashicons-calendar-alt"></span></a>
# <a href="https://www.facebook.com/FCNFAIC/" target="_blank"><span class="dashicons dashicons-facebook"></span></a>
# <a href="https://www.instagram.com/chugachavy/" target="_blank"><span class="dashicons dashicons-instagram"></span></a>
# <div class="footer-sm"><a href="https://www.fs.usda.gov/detail/chugach/"><strong>In partnership with Chugach National Forest</strong></a> <br/>
# 		    Copyright © 2020 Chugach National Forest Avalanche Information Center. All rights reserved. </div>
# </div>
# </div>
# </div>
# </footer>
# <script>
# (function($) {
# 	$(document).ready(function () {
# 	  $('.menu-button').on('click', function () {
# 	    $('.animated-icon3').toggleClass('open');
# 	  });
# 	});
#  })(jQuery);
# </script>
# <script>
# 		( function ( body ) {
# 			'use strict';
# 			body.className = body.className.replace( /\btribe-no-js\b/, 'tribe-js' );
# 		} )( document.body );
# 		</script>
# <!-- Custom Feeds for Instagram JS -->
# <script type="text/javascript">
# var sbiajaxurl = "https://www.cnfaic.org/wp-admin/admin-ajax.php";
#
# </script>
# <script> /* <![CDATA[ */var tribe_l10n_datatables = {"aria":{"sort_ascending":": activate to sort column ascending","sort_descending":": activate to sort column descending"},"length_menu":"Show _MENU_ entries","empty_table":"No data available in table","info":"Showing _START_ to _END_ of _TOTAL_ entries","info_empty":"Showing 0 to 0 of 0 entries","info_filtered":"(filtered from _MAX_ total entries)","zero_records":"No matching records found","search":"Search:","all_selected_text":"All items on this page were selected. ","select_all_link":"Select all pages","clear_selection":"Clear Selection.","pagination":{"all":"All","next":"Next","previous":"Previous"},"select":{"rows":{"0":"","_":": Selected %d rows","1":": Selected 1 row"}},"datepicker":{"dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesMin":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Prev","currentText":"Today","closeText":"Done","today":"Today","clear":"Clear"}};/* ]]> */ </script><script id="jquery-ui-core-js" src="https://www.cnfaic.org/wp-includes/js/jquery/ui/core.min.js?ver=1.12.1" type="text/javascript"></script>
# <script id="jquery-ui-tabs-js" src="https://www.cnfaic.org/wp-includes/js/jquery/ui/tabs.min.js?ver=1.12.1" type="text/javascript"></script>
# <script id="avantlink-ale-js" src="https://www.avantlink.com/ale/ale.php?p=27703&amp;pw=35183" type="text/javascript"></script>
# <script id="wp-embed-js" src="https://www.cnfaic.org/wp-includes/js/wp-embed.min.js?ver=5.6" type="text/javascript"></script>
# </body>
# </html>

# %%
#Saving stuff down here:
