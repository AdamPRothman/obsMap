# %% [markdown]
# CNFAIC Observation Map
# Goal:
# Make a map of recent (<7 days) observations.
#
# Ideas:
# - Custom date range
# - Icons based on dates
# - Professional only mode
#
# Steps:
# - Load observations and relevant data
# - Assign location to observation
# - Map observation
#     - Format tags and popups
#
# To Do:
# - Make popups nice
# - Add wx with different markers
# - github
# - hosting?

# %%
#Load libraries
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import folium
import numpy as np
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import datetime
import folium.plugins as plugins

# %%
#Observation dataframe
Obs = pd.DataFrame(columns = ('Location', 'Date', 'Observer','Lat','Lon'))
Obs
# Out:
# Empty DataFrame
# Columns: [Location, Date, Observer, Lat, Lon]
# Index: []

# %%
def getObs(url):
    #Open url and convert to soup
    html = urlopen(url).read()
    soup = BeautifulSoup(html)
    with open('./Observations/'+ url[36:-1], 'a') as file: file.write(str(soup))
    
    #Pull location
    location = str(soup.find('title'))
    location = location[7:location.find('|') - 1]
    
    #Pull observer info, first check for anonymous report
    if str(soup.select_one(
        'div[ class *= cnfaic_obs-table-browse-observations-byline]')) \
        == '<div class="cnfaic_obs-table-browse-observations-byline">Anonymous</div>':
        observer = 'Anonymous'
    else:
        observer = soup.select_one("span[class *= cnfaic_obs-table-browse-observations-byline]").text
        observer = observer[:-1]
        
    #Pull date
    date = soup.select('div[ class *= "top_meta"]')
    date = date[1].text
    formattedDate = formatTime(date)
    
    #Pull coordinates
    if len(soup.find_all("a", href=lambda href: href and "google" in href)) > 0:
        links = soup.find_all("a", href=lambda href: href and "google" in href)
        coords = str(links[0])
        coords = coords[coords.find('q='):coords.find("'>")]
        lat = float(coords[coords.find('=') + 1 : coords.find(',') - 1])
        lon = float(coords[coords.find(",") + 1 : coords.find('target') - 2])
    else:
        lat = float('NaN')
        lon = float('NaN')
        
    #Red Flags
    if soup.find_all('tr') != []:
        rows = soup.find_all('tr')
        flags = []
        for row in rows:
            cols = row.find_all('td')
            cols = [ele.text.strip() for ele in cols]
            flags.append([ele for ele in cols if ele]) 

        recentAvy = flags[0][1] == 'Yes'
        collapsing = flags[1][1] == 'Yes'
        cracking = flags[2][1] == 'Yes'
    else:
        recentAvy = False
        collapsing = False
        cracking = False
    
    #Create dataframe from data
    d = {'Date':[formattedDate],'Location':[location], 'Observer':[observer],'Lat':[lat], 'Lon': [lon], 
         'Recent Avy':[recentAvy], 'Collapsing' : [collapsing], 'Cracking' : [cracking],
         'url' : [url]}
    oneObs = pd.DataFrame(data = d)
    
    #Pull red flags

    return(oneObs)

# %%
def getUrls():
    url = 'https://www.cnfaic.org/view-observations/'
    html = urlopen(url).read()
    soup = BeautifulSoup(html)
    table = soup.find('table')
    links = table.find_all('a')
    urls = list()
    gallery = 'gallery'
    i = 0
    for link in range(len(links)):
        if gallery in str(links[link]):
            i = i
        else:
            url = str(links[link])
            url = url[ 9 : url.find('>') - 1]
            if (obsArchive['url'] == url).any():
                i = i
            else:
                urls.append(url)
                i += 1
    return(urls)

# %%
def getNewObs():
    newObs = pd.DataFrame()
    urls = getUrls()
    for i in range(len(urls)):  #Changed this
        newObs = newObs.append(getObs(urls[i]))
    
    newObs.reset_index(inplace = True, drop = True)
    newObs['url'] = urls
    return(newObs)

# %%
def addNewObs(obsArchive):
    newObs = getNewObs()
    #obsArchive = pd.read_pickle('./obsArchive.pkl')

    for i in range(len(newObs)):
        obsArchive = obsArchive.append(newObs.iloc[i])       
        #Save the soup to the observations folder
        #with open('./Observations/'+ url[36:-1], 'a') as file: file.write(str(soup))
            
    obsArchive = obsArchive.sort_values('Date', ascending = False)    
    obsArchive.reset_index(inplace = True, drop = True)

    obsArchive.to_pickle('./obsArchive.pkl')
    return(obsArchive)

# %%
obsArchive = addNewObs(obsArchive)
obsArchive
# Out:
#                   Date                                           Location  \
# 0  2020-12-01 11:15:00  Mount Marathon…East aspect above jeep trail to...
# 1  2020-11-30 08:47:00                                     Notch Mountain
# 2  2020-11-30 07:16:00                                Seattle Ridge Flats
# 3  2020-11-30 05:52:00                             Tincan- above treeline
# 4  2020-11-29 12:00:00                                           Sunburst
# 5  2020-11-29 09:39:00                               South Fork ER valley
# 6  2020-11-29 09:30:00                                         Tenderfoot
# 7  2020-11-29 07:06:00                                         Sunny Side
# 8  2020-11-29 04:00:00                                         Sunny Side
# 9  2020-11-29 02:53:00                    Overflight Recon Turnagain Pass
# 10 2020-11-29 02:00:00                                           Sunburst
# 11 2020-11-28 09:42:00                            Anchorage – Middle Fork
# 12 2020-11-28 09:04:00                                       Tincan trees
# 13 2020-11-28 08:25:00                                         Notch Mtn.
# 14 2020-11-28 06:00:00                                       Tincan Trees
# 15 2020-11-28 03:38:00                                Seattle Ridge Flats
# 16 2020-11-28 03:00:00                                           Manitoba
# 17 2020-11-28 01:00:00                                    Tincan Treeline
# 18 2020-11-27 07:08:00                                           Sunburst
# 19 2020-11-27 06:51:00                                             Eddies
# 20 2020-11-27 01:45:00  11/27 Skyscraper Mountain, Gully lookers left ...
# 21 2020-11-26 12:00:00                                       Tincan Trees
# 22 2020-11-26 12:00:00                                     Gold Mint Tour
# 23 2020-11-26 07:34:00                                      Seattle Ridge
# 24 2020-11-26 07:10:00                                          Micro Dot
# 25 2020-11-26 04:32:00                             South Fork Eagle River
# 26 2020-11-26 04:00:00                          near Fishhook Parking lot
# 27 2020-11-26 03:20:00                                           Sunburst
# 28 2020-11-26 01:00:00                                          Stairstep
# 29 2020-11-25 11:39:00                          Turnagain Pass -Moto side
# ..                 ...                                                ...
# 55 2020-11-21 06:59:00                              West Face of Sunburst
# 56 2020-11-21 05:02:00                                       Tincan Trees
# 57 2020-11-21 04:55:00                            Sunburst-Above Treeline
# 58 2020-11-21 02:30:00                              Tincan, Seattle Ridge
# 59 2020-11-21 02:00:00                                       Tincan Trees
# 60 2020-11-20 09:02:00                                             Peak 3
# 61 2020-11-20 05:23:00                                             Eddies
# 62 2020-11-19 01:19:00                              Good Hope Creek Basin
# 63 2020-11-18 06:38:00                            Base of Eddies Headwall
# 64 2020-11-18 03:00:00                                           Sunburst
# 65 2020-11-17 11:00:00                            Johns Cr S branch ridge
# 66 2020-11-17 08:55:00                                    Government Peak
# 67 2020-11-15 12:00:00                                           Mabitoba
# 61                         Todd Kelsey   60.800631 -149.128685      False
# 62              Gary Kuehn Professional  61.811352 -149.148469      False
# 63                     Heather Johnson   60.794430 -149.199667      False
# 64  Johnston-Bloom / DiJulia Forecaster  60.785637 -149.155207      False
# 65                          Gary Kuehn   60.643280 -149.498144      False
# 66            Blaine Smith Professional  61.752750 -149.275498      False
# 67                     Peter Wadsworth   60.685170 -149.429479      False
# 68                           Meg Smith   61.006439 -149.223013      False
# 69              Allie Barker Forecaster  61.778639 -149.259980      False
# 70                 Eric Roberts Kakiko   61.060851 -149.670277      False
# 71                         Tony Naciuk   60.787731 -149.164991      False
# 72                        Andy Moderow   60.799877 -149.127398      False
# 73                         Troy Tempel   60.822230 -149.196234      False
# 74                     Peter Wadsworth   60.704683 -149.351759       True
# 75                       James Carruba   61.791690 -149.264208      False
# 76                        Eric Roberts   60.787019 -149.164906      False
# 77                          Elias Holt   60.788737 -149.179754      False
# 78                           Malcolm H   60.794430 -149.199667      False
# 79   Wagner / Johnston-Bloom Forecaster  60.817961 -149.198294      False
# 80                    George Creighton   60.995496 -149.093237      False
# 81                        Andy Moderow   60.785344 -149.164476       True
# 82                            Anonymous  61.216874 -149.467287      False
# 83                                 b s   61.766294 -149.305496      False
# 84               Jed Workman Forecaster  61.782897 -149.268975       True
#
#    Collapsing Cracking                                                url  \
# 0       False    False  https://www.cnfaic.org/observations/mount-mara...
# 1       False    False  https://www.cnfaic.org/observations/notch-moun...
# 2       False    False  https://www.cnfaic.org/observations/seattle-ri...
# 3       False    False  https://www.cnfaic.org/observations/tincan-abo...
# 4       False    False  https://www.cnfaic.org/observations/sunburst-233/
# 5        True    False  https://www.cnfaic.org/observations/south-fork...
# 6        True    False  https://www.cnfaic.org/observations/tenderfoot...
# 7       False     True  https://www.cnfaic.org/observations/sunny-side-4/
# 8       False    False  https://www.cnfaic.org/observations/sunny-side-3/
# 9       False    False  https://www.cnfaic.org/observations/overflight...
# 10      False    False  https://www.cnfaic.org/observations/sunburst-232/
# 11      False    False  https://www.cnfaic.org/observations/anchorage-...
# 12      False    False  https://www.cnfaic.org/observations/tincan-tre...
# 13      False    False   https://www.cnfaic.org/observations/notch-mtn-3/
# 14      False    False  https://www.cnfaic.org/observations/tincan-tre...
# 15      False    False  https://www.cnfaic.org/observations/seattle-ri...
# 16       True    False   https://www.cnfaic.org/observations/manitoba-70/
# 17      False    False  https://www.cnfaic.org/observations/tincan-tre...
# 18       True     True  https://www.cnfaic.org/observations/sunburst-231/
# 19      False    False    https://www.cnfaic.org/observations/eddies-110/
# 20      False    False  https://www.cnfaic.org/observations/11-27-skys...
# 21      False    False  https://www.cnfaic.org/observations/tincan-tre...
# 22      False    False  https://www.cnfaic.org/observations/gold-mint-...
# 23       True    False  https://www.cnfaic.org/observations/seattle-ri...
# 24       True    False   https://www.cnfaic.org/observations/micro-dot-2/
# 25      False     True  https://www.cnfaic.org/observations/south-fork...
# 26      False    False  https://www.cnfaic.org/observations/near-fishh...
# 27      False    False  https://www.cnfaic.org/observations/sunburst-230/
# 28      False    False   https://www.cnfaic.org/observations/stairstep-3/
# 29      False    False  https://www.cnfaic.org/observations/turnagain-...
# ..        ...      ...                                                ...
# 55       True     True  https://www.cnfaic.org/observations/west-face-...
# 56      False    False  https://www.cnfaic.org/observations/tincan-tre...
# 57       True     True  https://www.cnfaic.org/observations/sunburst-a...
# 58      False    False  https://www.cnfaic.org/observations/tincan-sea...
# 59      False    False  https://www.cnfaic.org/observations/tincan-tre...
# 60      False     True     https://www.cnfaic.org/observations/peak-3-13/
# 61      False    False    https://www.cnfaic.org/observations/eddies-105/
# 62      False    False  https://www.cnfaic.org/observations/good-hope-...
# 63       True    False  https://www.cnfaic.org/observations/base-of-ed...
# 64      False    False  https://www.cnfaic.org/observations/sunburst-227/
# 65      False    False  https://www.cnfaic.org/observations/johns-cr-s...
# 66      False    False  https://www.cnfaic.org/observations/government...
# 67      False    False      https://www.cnfaic.org/observations/mabitoba/
# 68      False    False  https://www.cnfaic.org/observations/peak-conne...
# 69      False    False  https://www.cnfaic.org/observations/marmot-mou...
# 70      False    False  https://www.cnfaic.org/observations/rabbit-cre...
# 71       True    False    https://www.cnfaic.org/observations/tincan-289/
# 72       True    False    https://www.cnfaic.org/observations/eddies-104/
# 73       True    False  https://www.cnfaic.org/observations/seattle-ri...
# 74       True    False  https://www.cnfaic.org/observations/silvertip-...
# 75      False    False  https://www.cnfaic.org/observations/microdot-s...
# 76      False    False  https://www.cnfaic.org/observations/tincan-abo...
# 77       True    False    https://www.cnfaic.org/observations/tincan-288/
# 78      False     True  https://www.cnfaic.org/observations/tincan-com...
# 79       True     True  https://www.cnfaic.org/observations/seattle-ri...
# 80       True    False  https://www.cnfaic.org/observations/girdwood-v...
# 81       True    False    https://www.cnfaic.org/observations/tincan-287/
# 82      False    False  https://www.cnfaic.org/observations/hiland-fro...
# 83      False    False  https://www.cnfaic.org/observations/hatch-peak...
# 84       True     True  https://www.cnfaic.org/observations/marmot-tes...
#
#      ageGroup
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8   yesterday
# 9         NaN
# 10        NaN
# 11  yesterday
# 12  yesterday
# 13  yesterday
# 14  yesterday
# 15      3 day
# 16        NaN
# 17      3 day
# 18      3 day
# 19      3 day
# 20        NaN
# 21       week
# 22       week
# 23       week
# 24       week
# 25       week
# 26       week
# 27       week
# 28       week
# 29       week
# ..        ...
# 55        old
# 56        old
# 57        old
# 58        old
# 59        old
# 60        old
# 61        old
# 62        old
# 63        old
# 64        old
# 65        old
# 66        old
# 67        old
# 68        old
# 69        old
# 70        old
# 71        old
# 72        old
# 73        old
# 74        old
# 75        old
# 76        old
# 77        old
# 78        old
# 79        old
# 80        old
# 81        old
# 82        old
# 83        old
# 84        old
#
# [85 rows x 10 columns]

# %%
"""formattedDates = []
for i in range(len(obsArchive)):
    formattedDates.append(formatTime(obsArchive.iloc[i][0]))

obsArchive['Date'] = formattedDates
    """
# Out:
# "formattedDates = []\nfor i in range(len(obsArchive)):\n    formattedDates.append(formatTime(obsArchive.iloc[i][0]))\n\nobsArchive['Date'] = formattedDates\n    "

# %%
def formatTime(dateString):

    i = 0
    calendar = {'Jan':'01', 'Feb':'02', 'Mar':'03', 'Apr':'04', 'May':'05', 'Jun':'06', 'Jul':'07',
               'Aug':'08', 'Sep':'09', 'Oct':'10', 'Nov':'11', 'Dec':'12'}
    month = calendar[dateString[0:3]]

    day = dateString[dateString.find(',')-2:dateString.find(',')]
    if day[0] == ' ':
        day = '0' + day[1]

    year = dateString[dateString.find(',')+2:dateString.find(',')+6]
    year
    if dateString[-1] == 'm':
        time = dateString[-7:]
        if time[0] == ' ':
            time = '0' + time[1:]
    else:
        time = dateString[-5:]
        if time[0] == ' ':
            time = '0' + time[1:]

    dateString = str(year) + '-' + str(month) + '-' + str(day) + ' ' + time
    try:
        datetime.datetime.strptime(dateString, '%Y-%m-%d %H:%M%p')
    except:
        date = datetime.datetime.strptime(dateString, '%Y-%m-%d %H:%M')
    else:
        date = datetime.datetime.strptime(dateString, '%Y-%m-%d %H:%M%p')
    return(date)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-216-7bcd1454c6f3> in <module>
# ----> 1 obsArchive = addNewObs(obsArchive)
#
# <ipython-input-6-230c4606d0f8> in addNewObs(obsArchive)
#       6         obsArchive = obsArchive.append(newObs.iloc[i])
#       7             #Save the soup to the observations folder
# ----> 8         with open('./Observations/'+ url[36:-1], 'a') as file: file.write(str(soup))
#       9
#      10     obsArchive.sort_values('Date')
#
# NameError: name 'url' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8a86a26920b0> in <module>
# ----> 1 obsArchive.head()
#
# NameError: name 'obsArchive' is not defined

# %%
# Load USGS
url_base = 'http://server.arcgisonline.com/ArcGIS/rest/services/'
service = 'NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
tileset = url_base + service

# Create the map
m = folium.Map(location = [60.79443,-149.199667], zoom_start = 11, tiles = tileset,
               attr='USGS Style')


# Add markers to map
"""for i in range(len(obsArchive)):
    if str(obsArchive.iloc[i][3]) != 'nan':
        folium.Marker([obsArchive.iloc[i][3],obsArchive.iloc[i][4]], popup = 
                      obsArchive.iloc[i][1] + ' ' +
                      '<a href="%s" target="_blank">Link</a>' % obsArchive.iloc[i][8]).add_to(m)
    """
# Out:
# 'for i in range(len(obsArchive)):\n    if str(obsArchive.iloc[i][3]) != \'nan\':\n        folium.Marker([obsArchive.iloc[i][3],obsArchive.iloc[i][4]], popup = \n                      obsArchive.iloc[i][1] + \' \' +\n                      \'<a href="%s" target="_blank">Link</a>\' % obsArchive.iloc[i][8]).add_to(m)\n    '

# %%
# Out:
#                   Date                                      Location  \
# 0  2020-11-20 05:23:00                                        Eddies
# 1  2020-11-20 09:02:00                                        Peak 3
# 2  2020-11-19 01:19:00                         Good Hope Creek Basin
# 3  2020-11-18 06:38:00                       Base of Eddies Headwall
# 4  2020-11-18 03:00:00                                      Sunburst
# 5  2020-11-17 08:55:00                               Government Peak
# 6  2020-11-17 11:00:00                       Johns Cr S branch ridge
# 7  2020-11-15 07:24:00                               Marmot Mountain
# 8  2020-11-15 05:41:00                           Rabbit Creek Canyon
# 9  2020-11-15 04:46:00                                        Tincan
# 10 2020-11-15 03:00:00                                        Eddies
# 11 2020-11-15 02:00:00                                 Seattle Ridge
# 7       False      False    False
# 8       False      False    False
# 9       False       True    False
# 10      False       True    False
# 11      False       True    False
# 12      False      False    False
# 13      False      False    False
# 14       True       True    False
# 15      False      False    False
# 16      False      False    False
# 17      False       True    False
# 18      False      False     True
# 19      False       True     True
# 20      False       True    False
# 21       True       True    False
# 22      False      False    False
# 23      False      False    False
# 24       True       True     True
# 25      False      False    False
# 26      False      False    False
# 27       True      False    False
# 28      False       True    False
# 29      False       True    False
# ..        ...        ...      ...
# 43      False      False    False
# 44      False      False    False
# 45      False      False    False
# 46      False      False    False
# 47      False      False    False
# 48      False      False    False
# 49      False      False    False
# 50      False       True     True
# 51      False      False    False
# 52      False       True     True
# 53      False      False    False
# 54      False      False    False
# 55      False      False    False
# 56      False       True     True
# 57      False      False    False
# 58      False       True    False
# 59       True       True    False
# 60       True      False     True
# 61      False      False    False
# 62      False      False    False
# 63      False      False    False
# 64      False      False    False
# 65      False      False    False
# 66      False      False    False
# 67      False      False    False
# 68      False      False    False
# 69      False      False    False
# 70      False      False    False
# 71      False      False    False
# 72      False      False    False
#
#                                                   url
# 0     https://www.cnfaic.org/observations/eddies-105/
# 1      https://www.cnfaic.org/observations/peak-3-13/
# 2   https://www.cnfaic.org/observations/good-hope-...
# 3   https://www.cnfaic.org/observations/base-of-ed...
# 4   https://www.cnfaic.org/observations/sunburst-227/
# 5   https://www.cnfaic.org/observations/government...
# 6   https://www.cnfaic.org/observations/johns-cr-s...
# 7   https://www.cnfaic.org/observations/marmot-mou...
# 8   https://www.cnfaic.org/observations/rabbit-cre...
# 9     https://www.cnfaic.org/observations/tincan-289/
# 10    https://www.cnfaic.org/observations/eddies-104/
# 11  https://www.cnfaic.org/observations/seattle-ri...
# 12  https://www.cnfaic.org/observations/peak-conne...
# 13      https://www.cnfaic.org/observations/mabitoba/
# 14  https://www.cnfaic.org/observations/silvertip-...
# 15  https://www.cnfaic.org/observations/microdot-s...
# 16  https://www.cnfaic.org/observations/tincan-abo...
# 17    https://www.cnfaic.org/observations/tincan-288/
# 18  https://www.cnfaic.org/observations/tincan-com...
# 19  https://www.cnfaic.org/observations/seattle-ri...
# 20  https://www.cnfaic.org/observations/girdwood-v...
# 21    https://www.cnfaic.org/observations/tincan-287/
# 22  https://www.cnfaic.org/observations/hatch-peak...
# 23  https://www.cnfaic.org/observations/hiland-fro...
# 24  https://www.cnfaic.org/observations/marmot-tes...
# 25  https://www.cnfaic.org/observations/turnagain-...
# 26  https://www.cnfaic.org/observations/seattle-ri...
# 27    https://www.cnfaic.org/observations/eddies-109/
# 28  https://www.cnfaic.org/observations/sunburst-229/
# 29  https://www.cnfaic.org/observations/sunburst-w...
# ..                                                ...
# 43    https://www.cnfaic.org/observations/eddies-106/
# 44  https://www.cnfaic.org/observations/tincan-tre...
# 45   https://www.cnfaic.org/observations/summit-area/
# 46    https://www.cnfaic.org/observations/eddies-108/
# 47  https://www.cnfaic.org/observations/arctic-val...
# 48  https://www.cnfaic.org/observations/turnagain-...
# 49  https://www.cnfaic.org/observations/spirit-wal...
# 50  https://www.cnfaic.org/observations/west-face-...
# 51  https://www.cnfaic.org/observations/tincan-tre...
# 52  https://www.cnfaic.org/observations/sunburst-a...
# 53  https://www.cnfaic.org/observations/tincan-sea...
# 54  https://www.cnfaic.org/observations/tincan-tre...
# 55  https://www.cnfaic.org/observations/arctic-val...
# 56  https://www.cnfaic.org/observations/sunburst-231/
# 57    https://www.cnfaic.org/observations/eddies-110/
# 58  https://www.cnfaic.org/observations/seattle-ri...
# 59   https://www.cnfaic.org/observations/micro-dot-2/
# 60  https://www.cnfaic.org/observations/south-fork...
# 61  https://www.cnfaic.org/observations/near-fishh...
# 62  https://www.cnfaic.org/observations/sunburst-230/
# 63   https://www.cnfaic.org/observations/stairstep-3/
# 64  https://www.cnfaic.org/observations/tincan-tre...
# 65  https://www.cnfaic.org/observations/gold-mint-...
# 66  https://www.cnfaic.org/observations/tincan-tre...
# 67  https://www.cnfaic.org/observations/sunny-side-3/
# 68   https://www.cnfaic.org/observations/notch-mtn-3/
# 69  https://www.cnfaic.org/observations/tincan-tre...
# 70  https://www.cnfaic.org/observations/seattle-ri...
# 71  https://www.cnfaic.org/observations/anchorage-...
# 72  https://www.cnfaic.org/observations/tincan-tre...
#
# [73 rows x 9 columns]

# %%
#Filter obs archive into 3 groups based on age of obs
today = datetime.datetime.today()
oneDay = datetime.timedelta(days = 1.5)
threeDays = datetime.timedelta(days = 2.5)
oneWeek = datetime.timedelta(days = 7)
i = 0


for i in range(len(obsArchive)):
    if obsArchive.iloc[i][0] + oneDay > today:
        obsArchive['ageGroup'][i] = 'yesterday'
    elif obsArchive.iloc[i][0] + threeDays > today:
        obsArchive['ageGroup'][i] = '3 day'
    elif obsArchive.iloc[i][0] + oneWeek > today:
        obsArchive['ageGroup'][i] = 'week'
    else:
        obsArchive['ageGroup'][i] = 'old'


obsArchive
# Out:
#                   Date                                      Location  \
# 0  2020-11-20 05:23:00                                        Eddies
# 1  2020-11-20 09:02:00                                        Peak 3
# 2  2020-11-19 01:19:00                         Good Hope Creek Basin
# 3  2020-11-18 06:38:00                       Base of Eddies Headwall
# 4  2020-11-18 03:00:00                                      Sunburst
# 5  2020-11-17 08:55:00                               Government Peak
# 6  2020-11-17 11:00:00                       Johns Cr S branch ridge
# 7  2020-11-15 07:24:00                               Marmot Mountain
# 8  2020-11-15 05:41:00                           Rabbit Creek Canyon
# 9  2020-11-15 04:46:00                                        Tincan
# 10 2020-11-15 03:00:00                                        Eddies
# 11 2020-11-15 02:00:00                                 Seattle Ridge
# 12 2020-11-15 10:00:00  Peak connecting Penguin &amp; Fishes Breathe
# 13 2020-11-15 12:00:00                                      Mabitoba
# 14 2020-11-14 08:28:00                              Silvertip Valley
# 15 2020-11-14 05:52:00                          Microdot, south side
# 16 2020-11-14 05:39:00                         Tincan-Above Treeline
# 17 2020-11-13 05:10:00                                        Tincan
# 18 2020-11-13 04:40:00           Tincan Common Bowl and Tincan Trees
# 19 2020-11-13 03:33:00     Seattle Ridge – Sunnyside/Repeat Offender
# 20 2020-11-12 08:09:00                               Girdwood Valley
# 16                                 Eric Roberts   60.787019 -149.164906
# 17                                   Elias Holt   60.788737 -149.179754
# 18                                    Malcolm H   60.794430 -149.199667
# 19            Wagner / Johnston-Bloom Forecaster  60.817961 -149.198294
# 20                             George Creighton   60.995496 -149.093237
# 21                                 Andy Moderow   60.785344 -149.164476
# 22                                          b s   61.766294 -149.305496
# 23                                     Anonymous  61.216874 -149.467287
# 24                        Jed Workman Forecaster  61.782897 -149.268975
# 25                              Graham Predeger   60.814864 -149.191084
# 26                                  Zach Behney   60.817041 -149.190226
# 27                                   Elias Holt   60.794430 -149.199667
# 28            Johnston-Bloom / Cleary Forecaster  60.763929 -149.187136
# 29                               Brooke Edwards   60.765606 -149.192114
# ..                                           ...        ...         ...
# 43                     Andrew Schauer Forecaster  60.802557 -149.129372
# 44                                  Tony Naciuk   60.790245 -149.172201
# 45                                 Jacob Swartz   60.643280 -149.498144
# 46                                    Alan Abel   60.800631 -149.126539
# 47  Michael Olive (Anchorage Nordic Ski Patrol)   61.251463 -149.507832
# 48                                     W Wagner   60.794430 -149.199667
# 49                              Stephen Ellison   60.658768 -149.392401
# 50                                 Max Durtschi   60.794430 -149.199667
# 51                                 Andy Moderow   60.789910 -149.177694
# 52                                 Eric Roberts   60.766570 -149.197178
# 53                               Andrew Schauer   60.785050 -149.165678
# 54                             Tully Ward-Hamer   60.794430 -149.199667
# 55                                 John Sievert   61.252354 -149.508142
# 56                     Andrew Schauer Forecaster        NaN         NaN
# 57                    Eric Roberts Adam Rothman   60.794430 -149.199667
# 58                     Andrew Schauer Forecaster  60.820052 -149.185554
# 59                                 Dylan Lenzie         NaN         NaN
# 60                                   Gary Kuehn   61.215469 -149.470205
# 61                                  Shane Dixon   61.770111 -149.262023
# 62              Brooke Edwards / Nick D’Alessio   60.767283 -149.194860
# 63                                     Anonymous        NaN         NaN
# 64                                  Tony Naciuk   60.790077 -149.175978
# 65                    Andrew/Kai Dennis/McGrath   61.776383 -149.183659
# 66                                 Eeva Latosuo   60.789156 -149.170828
# 67                              Peter Wadsworth   60.766738 -149.256337
# 68                               Andrew Schauer   60.982342 -149.039593
# 69                             Tully Ward-Hamer   60.790077 -149.176664
# 70                           W Wagner Forecaster  60.786223 -149.219236
# 71                                 Eric Parsons   61.112640 -149.666929
# 72                                Bob Lieberman   60.790999 -149.173231
#
#    Recent Avy Collapsing Cracking  \
# 0       False      False    False
# 1       False      False     True
# 2       False      False    False
# 3       False       True    False
# 4       False      False    False
# 5       False      False    False
# 6       False      False    False
# 7       False      False    False
# 8       False      False    False
# 9       False       True    False
# 10      False       True    False
# 11      False       True    False
# 12      False      False    False
# 13      False      False    False
# 14       True       True    False
# 15      False      False    False
# 16      False      False    False
# 17      False       True    False
# 18      False      False     True
# 19      False       True     True
# 20      False       True    False
# 21       True       True    False
# 22      False      False    False
# 23      False      False    False
# 24       True       True     True
# 25      False      False    False
# 26      False      False    False
# 27       True      False    False
# 28      False       True    False
# 29      False       True    False
# ..        ...        ...      ...
# 43      False      False    False
# 44      False      False    False
# 45      False      False    False
# 46      False      False    False
# 47      False      False    False
# 48      False      False    False
# 49      False      False    False
# 50      False       True     True
# 51      False      False    False
# 52      False       True     True
# 53      False      False    False
# 54      False      False    False
# 55      False      False    False
# 56      False       True     True
# 57      False      False    False
# 58      False       True    False
# 59       True       True    False
# 60       True      False     True
# 61      False      False    False
# 62      False      False    False
# 63      False      False    False
# 64      False      False    False
# 65      False      False    False
# 66      False      False    False
# 67      False      False    False
# 68      False      False    False
# 69      False      False    False
# 70      False      False    False
# 71      False      False    False
# 72      False      False    False
#
#                                                   url   ageGroup
# 0     https://www.cnfaic.org/observations/eddies-105/        old
# 1      https://www.cnfaic.org/observations/peak-3-13/        old
# 2   https://www.cnfaic.org/observations/good-hope-...        old
# 3   https://www.cnfaic.org/observations/base-of-ed...        old
# 4   https://www.cnfaic.org/observations/sunburst-227/        old
# 5   https://www.cnfaic.org/observations/government...        old
# 6   https://www.cnfaic.org/observations/johns-cr-s...        old
# 7   https://www.cnfaic.org/observations/marmot-mou...        old
# 8   https://www.cnfaic.org/observations/rabbit-cre...        old
# 9     https://www.cnfaic.org/observations/tincan-289/        old
# 10    https://www.cnfaic.org/observations/eddies-104/        old
# 11  https://www.cnfaic.org/observations/seattle-ri...        old
# 12  https://www.cnfaic.org/observations/peak-conne...        old
# 13      https://www.cnfaic.org/observations/mabitoba/        old
# 14  https://www.cnfaic.org/observations/silvertip-...        old
# 15  https://www.cnfaic.org/observations/microdot-s...        old
# 16  https://www.cnfaic.org/observations/tincan-abo...        old
# 17    https://www.cnfaic.org/observations/tincan-288/        old
# 18  https://www.cnfaic.org/observations/tincan-com...        old
# 19  https://www.cnfaic.org/observations/seattle-ri...        old
# 20  https://www.cnfaic.org/observations/girdwood-v...        old
# 21    https://www.cnfaic.org/observations/tincan-287/        old
# 22  https://www.cnfaic.org/observations/hatch-peak...        old
# 23  https://www.cnfaic.org/observations/hiland-fro...        old
# 24  https://www.cnfaic.org/observations/marmot-tes...        old
# 25  https://www.cnfaic.org/observations/turnagain-...       week
# 26  https://www.cnfaic.org/observations/seattle-ri...       week
# 27    https://www.cnfaic.org/observations/eddies-109/       week
# 28  https://www.cnfaic.org/observations/sunburst-229/       week
# 29  https://www.cnfaic.org/observations/sunburst-w...       week
# ..                                                ...        ...
# 43    https://www.cnfaic.org/observations/eddies-106/        old
# 44  https://www.cnfaic.org/observations/tincan-tre...        old
# 45   https://www.cnfaic.org/observations/summit-area/        old
# 46    https://www.cnfaic.org/observations/eddies-108/        old
# 47  https://www.cnfaic.org/observations/arctic-val...        old
# 48  https://www.cnfaic.org/observations/turnagain-...        old
# 49  https://www.cnfaic.org/observations/spirit-wal...        old
# 50  https://www.cnfaic.org/observations/west-face-...        old
# 51  https://www.cnfaic.org/observations/tincan-tre...        old
# 52  https://www.cnfaic.org/observations/sunburst-a...        old
# 53  https://www.cnfaic.org/observations/tincan-sea...        old
# 54  https://www.cnfaic.org/observations/tincan-tre...        old
# 55  https://www.cnfaic.org/observations/arctic-val...        old
# 56  https://www.cnfaic.org/observations/sunburst-231/      3 day
# 57    https://www.cnfaic.org/observations/eddies-110/      3 day
# 58  https://www.cnfaic.org/observations/seattle-ri...       week
# 59   https://www.cnfaic.org/observations/micro-dot-2/       week
# 60  https://www.cnfaic.org/observations/south-fork...       week
# 61  https://www.cnfaic.org/observations/near-fishh...       week
# 62  https://www.cnfaic.org/observations/sunburst-230/       week
# 63   https://www.cnfaic.org/observations/stairstep-3/       week
# 64  https://www.cnfaic.org/observations/tincan-tre...       week
# 65  https://www.cnfaic.org/observations/gold-mint-...       week
# 66  https://www.cnfaic.org/observations/tincan-tre...      3 day
# 67  https://www.cnfaic.org/observations/sunny-side-3/  yesterday
# 68   https://www.cnfaic.org/observations/notch-mtn-3/  yesterday
# 69  https://www.cnfaic.org/observations/tincan-tre...  yesterday
# 70  https://www.cnfaic.org/observations/seattle-ri...      3 day
# 71  https://www.cnfaic.org/observations/anchorage-...  yesterday
# 72  https://www.cnfaic.org/observations/tincan-tre...  yesterday
#
# [73 rows x 10 columns]

# %%
dfYes = obsArchive[obsArchive['ageGroup'].isin(['yesterday'])]
df3day = obsArchive[obsArchive['ageGroup'].isin(['3 day'])]
dfWeek = obsArchive[obsArchive['ageGroup'].isin(['week'])]

# %%
fgObs = folium.FeatureGroup(name = 'Observations')
m.add_child(fgObs)
gYes = folium.plugins.FeatureGroupSubGroup(fgObs, 'Yesterday')
g3day = folium.plugins.FeatureGroupSubGroup(fgObs, '3 Days')
gWeek = folium.plugins.FeatureGroupSubGroup(fgObs, 'One Week')
subGroups = [gYes, g3day, gWeek]


frames = [dfYes, df3day, dfWeek]
colors = ['red', 'green', 'blue']

for i in range(len(frames)):
    m.add_child(subGroups[i])
    for j in range(len(frames[i])):
        if str(frames[i].iloc[j][3]) != 'nan':
            subGroups[i].add_child(
                folium.Marker([frames[i].iloc[j][3],
                frames[i].iloc[j][4]], 
                popup = frames[i].iloc[j][1] + ' ' +
                '<a href="%s" target="_blank">Link</a>' % frames[i].iloc[j][8],
                icon = folium.Icon(color = colors[i])))

folium.LayerControl().add_to(m)

# %%
frames[0]
# Out:
#                   Date                 Location           Observer        Lat  \
# 67 2020-11-29 04:00:00               Sunny Side   Peter Wadsworth   60.766738
# 68 2020-11-28 08:25:00               Notch Mtn.    Andrew Schauer   60.982342
# 69 2020-11-28 06:00:00             Tincan Trees  Tully Ward-Hamer   60.790077
# 71 2020-11-28 09:42:00  Anchorage – Middle Fork      Eric Parsons   61.112640
# 72 2020-11-28 09:04:00             Tincan trees     Bob Lieberman   60.790999
#
#            Lon Recent Avy Collapsing Cracking  \
# 67 -149.256337      False      False    False
# 68 -149.039593      False      False    False
# 69 -149.176664      False      False    False
# 71 -149.666929      False      False    False
# 72 -149.173231      False      False    False
#
#                                                   url   ageGroup
# 67  https://www.cnfaic.org/observations/sunny-side-3/  yesterday
# 68   https://www.cnfaic.org/observations/notch-mtn-3/  yesterday
# 69  https://www.cnfaic.org/observations/tincan-tre...  yesterday
# 71  https://www.cnfaic.org/observations/anchorage-...  yesterday
# 72  https://www.cnfaic.org/observations/tincan-tre...  yesterday

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
