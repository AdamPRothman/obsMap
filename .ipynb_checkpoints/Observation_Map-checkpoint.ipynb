# %% [markdown]
# CNFAIC Observation Map
# Goal:
# Make a map of recent (<7 days) observations.
#
# Ideas:
# - Custom date range
# - Icons based on dates
# - Professional only mode
#
# Steps:
# - Load observations and relevant data
# - Assign location to observation
# - Map observation
#     - Format tags and popups
#
# To Do:
# - Fix flag count
# - Text encoding, might have fixed this going forward with decode/encode
# - Layer Options
# - Make popups nice
#     - Add border, for slides only?
#     - Add icon for slide
# - Add wx with different markers
# - Create website with legend around map
#
# - hosting?

# %%
#Load libraries
import base64
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
import folium
from folium import IFrame
import folium.plugins as plugins
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import datetime

# %%
#Observation dataframe
Obs = pd.DataFrame(columns = ('Location', 'Date', 'Observer','Lat','Lon'))
Obs

#read observation archive

obsArchive = pd.read_pickle('./obsArchive.pkl')

# %%
def getObs(url):
    #Open url and convert to soup
    html = urlopen(url).read()
    soup = BeautifulSoup(html)
    with open('./Observations/'+ url[36:-1], 'a') as file: file.write(str(soup))
    
    #Pull location
    location = str(soup.find('title'))
    location = location.replace("[\\u2018\\u2019]", "'") #Replace curly single quote with straight
    location = location[7:location.find('|') - 1]
    
    #Pull observer info, first check for anonymous report
    if str(soup.select_one(
        'div[ class *= cnfaic_obs-table-browse-observations-byline]')) \
        == '<div class="cnfaic_obs-table-browse-observations-byline">Anonymous</div>':
        observer = 'Anonymous'
    else:
        observer = soup.select_one("span[class *= cnfaic_obs-table-browse-observations-byline]").text
        observer = observer[:-1]
        
    #Pull date
    date = soup.select('div[ class *= "top_meta"]')
    date = date[1].text
    formattedDate = formatTime(date)
    
    #Pull coordinates
    if len(soup.find_all("a", href=lambda href: href and "google" in href)) > 0:
        links = soup.find_all("a", href=lambda href: href and "google" in href)
        coords = str(links[0])
        coords = coords[coords.find('q='):coords.find("'>")]
        lat = float(coords[coords.find('=') + 1 : coords.find(',') - 1])
        lon = float(coords[coords.find(",") + 1 : coords.find('target') - 2])
    else:
        lat = float('NaN')
        lon = float('NaN')
        
    #Red Flags
    if soup.find_all('tr') != []:
        rows = soup.find_all('tr')
        flags = []
        for row in rows:
            cols = row.find_all('td')
            cols = [ele.text.strip() for ele in cols]
            flags.append([ele for ele in cols if ele]) 

        recentAvy = flags[0][1] == 'Yes'
        collapsing = flags[1][1] == 'Yes'
        cracking = flags[2][1] == 'Yes'
    else:
        recentAvy = False
        collapsing = False
        cracking = False
    
    flagCount = 0
    if recentAvy == True:
        flagCount += 1
    if collapsing == True:
        flagCount += 1
    if cracking == True:
        flagCount += 1
        
    
    #Create dataframe from data
    d = {'Date':[formattedDate],'Location':[location], 'Observer':[observer],'Lat':[lat], 
         'Lon': [lon], 'Recent Avy':[recentAvy], 'Collapsing' : [collapsing], 
         'Cracking' : [cracking], 'flagCount' : flagCount, 'url' : [url]}
    oneObs = pd.DataFrame(data = d)
    
    #Pull red flags

    return(oneObs)

# %%
getObs('https://www.cnfaic.org/observations/pinnacle-b').iloc[0][1]
# Out:
# 'Eddie’s'

# %%
def getUrls():
    url = 'https://www.cnfaic.org/view-observations/'
    html = urlopen(url).read()
    soup = BeautifulSoup(html)
    table = soup.find('table')
    links = table.find_all('a')
    urls = list()
    gallery = 'gallery'
    i = 0
    for link in range(len(links)):
        if gallery in str(links[link]):
            i = i
        else:
            url = str(links[link])
            url = url[ 9 : url.find('>') - 1]
            if (obsArchive['url'] == url).any():
                i = i
            else:
                urls.append(url)
                i += 1
    return(urls)

# %%
def getNewObs():
    newObs = pd.DataFrame()
    urls = getUrls()
    for i in range(len(urls)):  #Changed this
        newObs = newObs.append(getObs(urls[i]))
    
    newObs.reset_index(inplace = True, drop = True)
    newObs['url'] = urls
    return(newObs)

# %%
def addNewObs(obsArchive):
    newObs = getNewObs()

    for i in range(len(newObs)):
        obsArchive = obsArchive.append(newObs.iloc[i])       
        #Save the soup to the observations folder
        #with open('./Observations/'+ url[36:-1], 'a') as file: file.write(str(soup))
            
    obsArchive = obsArchive.sort_values('Date', ascending = False)    
    obsArchive.reset_index(inplace = True, drop = True)

    obsArchive.to_pickle('./obsArchive.pkl')
    return(obsArchive)

# %%
def formatTime(dateString):

    i = 0
    calendar = {'Jan':'01', 'Feb':'02', 'Mar':'03', 'Apr':'04', 'May':'05', 'Jun':'06', 'Jul':'07',
               'Aug':'08', 'Sep':'09', 'Oct':'10', 'Nov':'11', 'Dec':'12'}
    month = calendar[dateString[0:3]]

    day = dateString[dateString.find(',')-2:dateString.find(',')]
    if day[0] == ' ':
        day = '0' + day[1]

    year = dateString[dateString.find(',')+2:dateString.find(',')+6]
    year
    if dateString[-1] == 'm':
        time = dateString[-7:]
        if time[0] == ' ':
            time = '0' + time[1:]
    else:
        time = dateString[-5:]
        if time[0] == ' ':
            time = '0' + time[1:]

    dateString = str(year) + '-' + str(month) + '-' + str(day) + ' ' + time
    try:
        datetime.datetime.strptime(dateString, '%Y-%m-%d %H:%M%p')
    except:
        date = datetime.datetime.strptime(dateString, '%Y-%m-%d %H:%M')
    else:
        date = datetime.datetime.strptime(dateString, '%Y-%m-%d %H:%M%p')
    return(date)

# %%
obsArchive = addNewObs(obsArchive)
obsArchive
# Out:
#                    Date                                      Location  \
# 0   2020-12-13 04:04:00               Sunburst Meadows above Treeline
# 1   2020-12-13 02:00:00           Motorized Uptrack / Repeat Offender
# 2   2020-12-12 08:31:00                                       Eddie’s
# 3   2020-12-12 07:05:00                                     Raggedtop
# 4   2020-12-12 02:09:00              Iditarod Trail from Center Ridge
# 5   2020-12-12 01:00:00                               Carter-Crescent
# 6   2020-12-11 10:01:00                                Notch Mountain
# 7   2020-12-11 08:32:00                                      Manitoba
# 8   2020-12-11 06:04:00                                 Tincan Alpine
# 9   2020-12-11 05:04:00                                 Valley of Sin
# 10  2020-12-11 04:04:00                                    Lynx Creek
# 11  2020-12-10 10:35:00                                SE Summit Pass
# 12  2020-12-10 09:17:00                           South – Summit Lake
# 13  2020-12-10 09:08:00                                      Sunburst
# 14  2020-12-10 03:00:00                                   Cornbiscuit
# 15  2020-12-10 01:00:00                                Pinnacle Basin
# 16  2020-12-09 07:25:00                                      Sunburst
# 17  2020-12-09 03:05:00                       Lost Lake Area snowfall
# 18  2020-12-08 07:51:00                                    Tenderfoot
# 19  2020-12-08 02:00:00                                 Seattle Ridge
# 15                           Dylan Lenzie         NaN         NaN      False
# 16     Johnston-Bloom / Roberts Forecaster  60.764013 -149.187565       True
# 17                            Alex McLain   60.259605 -149.433948      False
# 18                         Nick D'Alessio   60.637396 -149.488874      False
# 19                                J Davis   60.821811 -149.190912      False
# 20        Schauer /Eric Roberts Forecaster  60.786831 -149.164777      False
# 21           Marissa/Mary Bieger/Gianotti   60.794430 -149.199667       True
# 22         Aleph Johnston-Bloom Forecaster  60.981634 -149.036245      False
# 23                             Amy Holman   60.794430 -149.199667      False
# 24                            Troy Tempel   61.217783 -149.470549      False
# 25                            Tony Naciuk   60.750009 -149.216833      False
# 26                         William Finley   60.746318 -149.192801       True
# 27                          George /Waldo   60.694728 -149.384375      False
# 28                             Sam McLain   60.480602 -149.465877      False
# 29       Mary and Jocelyn Gianotti/Cramer   60.797700 -149.120960       True
# ..                                     ...        ...         ...        ...
# 104                          Max Durtschi   60.794430 -149.199667      False
# 105                          Andy Moderow   60.789910 -149.177694      False
# 106                          Eric Roberts   60.766570 -149.197178      False
# 107                        Andrew Schauer   60.785050 -149.165678      False
# 108                      Tully Ward-Hamer   60.794430 -149.199667      False
# 109                           Caleb Rauch   61.079784 -149.659548      False
# 110                           Todd Kelsey   60.800631 -149.128685      False
# 111                Gary Kuehn Professional  61.811352 -149.148469      False
# 112                       Heather Johnson   60.794430 -149.199667      False
# 113    Johnston-Bloom / DiJulia Forecaster  60.785637 -149.155207      False
# 114                            Gary Kuehn   60.643280 -149.498144      False
# 115              Blaine Smith Professional  61.752750 -149.275498      False
# 116                       Peter Wadsworth   60.685170 -149.429479      False
# 117                             Meg Smith   61.006439 -149.223013      False
# 118                Allie Barker Forecaster  61.778639 -149.259980      False
# 119                   Eric Roberts Kakiko   61.060851 -149.670277      False
# 120                           Tony Naciuk   60.787731 -149.164991      False
# 121                          Andy Moderow   60.799877 -149.127398      False
# 122                           Troy Tempel   60.822230 -149.196234      False
# 123                       Peter Wadsworth   60.704683 -149.351759       True
# 124                         James Carruba   61.791690 -149.264208      False
# 125                          Eric Roberts   60.787019 -149.164906      False
# 126                            Elias Holt   60.788737 -149.179754      False
# 127                             Malcolm H   60.794430 -149.199667      False
# 128     Wagner / Johnston-Bloom Forecaster  60.817961 -149.198294      False
# 129                      George Creighton   60.995496 -149.093237      False
# 130                          Andy Moderow   60.785344 -149.164476       True
# 131                              Anonymous  61.216874 -149.467287      False
# 132                                   b s   61.766294 -149.305496      False
# 133                 Jed Workman Forecaster  61.782897 -149.268975       True
#
#     Collapsing Cracking  flagCount  \
# 0        False    False          0
# 1        False    False          0
# 2        False    False          0
# 3        False    False          0
# 4        False    False          0
# 5        False    False          0
# 6        False    False          0
# 7        False    False          0
# 8        False    False          0
# 9        False    False          0
# 10       False    False          0
# 11       False    False          0
# 12       False    False          0
# 13       False    False          0
# 14       False    False          0
# 15        True     True          2
# 16       False    False          1
# 17       False    False          0
# 18       False    False          0
# 19       False    False          0
# 20        True     True          2
# 21       False    False          1
# 22       False    False          0
# 23        True    False          1
# 24       False    False          0
# 25        True    False          1
# 26       False    False          1
# 27       False    False          0
# 28       False    False          0
# 29       False    False          1
# ..         ...      ...        ...
# 104       True     True          2
# 105      False    False          0
# 106       True     True          2
# 107      False    False          0
# 108      False    False          0
# 109      False     True          1
# 110      False    False          0
# 111      False    False          0
# 112       True    False          1
# 113      False    False          0
# 114      False    False          0
# 115      False    False          0
# 116      False    False          0
# 117      False    False          0
# 118      False    False          0
# 119      False    False          0
# 120       True    False          1
# 121       True    False          1
# 122       True    False          1
# 123       True    False          2
# 124      False    False          0
# 125      False    False          0
# 126       True    False          1
# 127      False     True          1
# 128       True     True          2
# 129       True    False          1
# 130       True    False          2
# 131      False    False          0
# 132      False    False          0
# 133       True     True          3
#
#                                                    url ageGroup
# 0    https://www.cnfaic.org/observations/sunburst-m...      NaN
# 1    https://www.cnfaic.org/observations/motorized-...      NaN
# 2      https://www.cnfaic.org/observations/eddies-111/      NaN
# 3    https://www.cnfaic.org/observations/raggedtop-17/      NaN
# 4    https://www.cnfaic.org/observations/iditarod-t...      NaN
# 5    https://www.cnfaic.org/observations/carter-cre...      NaN
# 6    https://www.cnfaic.org/observations/notch-moun...      NaN
# 7     https://www.cnfaic.org/observations/manitoba-71/      NaN
# 8    https://www.cnfaic.org/observations/tincan-alp...      NaN
# 9    https://www.cnfaic.org/observations/valley-of-...      NaN
# 10   https://www.cnfaic.org/observations/lynx-creek...      NaN
# 11   https://www.cnfaic.org/observations/se-summit-...      NaN
# 12   https://www.cnfaic.org/observations/south-summ...      NaN
# 13   https://www.cnfaic.org/observations/sunburst-235/      NaN
# 14   https://www.cnfaic.org/observations/cornbiscui...      NaN
# 15   https://www.cnfaic.org/observations/pinnacle-b...      NaN
# 16   https://www.cnfaic.org/observations/sunburst-234/      NaN
# 17   https://www.cnfaic.org/observations/lost-lake-...      NaN
# 18   https://www.cnfaic.org/observations/tenderfoot...      NaN
# 19   https://www.cnfaic.org/observations/seattle-ri...      NaN
# 20     https://www.cnfaic.org/observations/tincan-295/      NaN
# 21   https://www.cnfaic.org/observations/tincan-tre...      NaN
# 22   https://www.cnfaic.org/observations/notch-moun...      NaN
# 23   https://www.cnfaic.org/observations/tincan-tre...      NaN
# 24   https://www.cnfaic.org/observations/south-fork...      NaN
# 25   https://www.cnfaic.org/observations/cornbiscui...      NaN
# 26   https://www.cnfaic.org/observations/cornbiscui...      NaN
# 27    https://www.cnfaic.org/observations/silvertip-8/      NaN
# 28   https://www.cnfaic.org/observations/carter-lak...      NaN
# 29   https://www.cnfaic.org/observations/eddies-abo...      NaN
# ..                                                 ...      ...
# 104  https://www.cnfaic.org/observations/west-face-...      old
# 105  https://www.cnfaic.org/observations/tincan-tre...      old
# 106  https://www.cnfaic.org/observations/sunburst-a...      old
# 107  https://www.cnfaic.org/observations/tincan-sea...      old
# 108  https://www.cnfaic.org/observations/tincan-tre...      old
# 109     https://www.cnfaic.org/observations/peak-3-13/      old
# 110    https://www.cnfaic.org/observations/eddies-105/      old
# 111  https://www.cnfaic.org/observations/good-hope-...      old
# 112  https://www.cnfaic.org/observations/base-of-ed...      old
# 113  https://www.cnfaic.org/observations/sunburst-227/      old
# 114  https://www.cnfaic.org/observations/johns-cr-s...      old
# 115  https://www.cnfaic.org/observations/government...      old
# 116      https://www.cnfaic.org/observations/mabitoba/      old
# 117  https://www.cnfaic.org/observations/peak-conne...      old
# 118  https://www.cnfaic.org/observations/marmot-mou...      old
# 119  https://www.cnfaic.org/observations/rabbit-cre...      old
# 120    https://www.cnfaic.org/observations/tincan-289/      old
# 121    https://www.cnfaic.org/observations/eddies-104/      old
# 122  https://www.cnfaic.org/observations/seattle-ri...      old
# 123  https://www.cnfaic.org/observations/silvertip-...      old
# 124  https://www.cnfaic.org/observations/microdot-s...      old
# 125  https://www.cnfaic.org/observations/tincan-abo...      old
# 126    https://www.cnfaic.org/observations/tincan-288/      old
# 127  https://www.cnfaic.org/observations/tincan-com...      old
# 128  https://www.cnfaic.org/observations/seattle-ri...      old
# 129  https://www.cnfaic.org/observations/girdwood-v...      old
# 130    https://www.cnfaic.org/observations/tincan-287/      old
# 131  https://www.cnfaic.org/observations/hiland-fro...      old
# 132  https://www.cnfaic.org/observations/hatch-peak...      old
# 133  https://www.cnfaic.org/observations/marmot-tes...      old
#
# [134 rows x 11 columns]

# %%
"""formattedDates = []
for i in range(len(obsArchive)):
    formattedDates.append(formatTime(obsArchive.iloc[i][0]))

obsArchive['Date'] = formattedDates
    """
# Out:
# "formattedDates = []\nfor i in range(len(obsArchive)):\n    formattedDates.append(formatTime(obsArchive.iloc[i][0]))\n\nobsArchive['Date'] = formattedDates\n    "

# %%
# Load USGS
url_base = 'http://server.arcgisonline.com/ArcGIS/rest/services/'
service = 'NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
tileset = url_base + service

# Create the map
m = folium.Map(location = [60.79443,-149.199667], zoom_start = 11, tiles = tileset,
               attr='USGS Style')


# Add markers to map
"""for i in range(len(obsArchive)):
    if str(obsArchive.iloc[i][3]) != 'nan':
        folium.Marker([obsArchive.iloc[i][3],obsArchive.iloc[i][4]], popup = 
                      obsArchive.iloc[i][1] + ' ' +
                      '<a href="%s" target="_blank">Link</a>' % obsArchive.iloc[i][8]).add_to(m)
    """
# Out:
# 'for i in range(len(obsArchive)):\n    if str(obsArchive.iloc[i][3]) != \'nan\':\n        folium.Marker([obsArchive.iloc[i][3],obsArchive.iloc[i][4]], popup = \n                      obsArchive.iloc[i][1] + \' \' +\n                      \'<a href="%s" target="_blank">Link</a>\' % obsArchive.iloc[i][8]).add_to(m)\n    '

# %%
#Filter obs archive into 3 groups based on age of obs
today = datetime.datetime.today()
oneDay = datetime.timedelta(days = 1.5)
threeDays = datetime.timedelta(days = 2.5)
oneWeek = datetime.timedelta(days = 7)
i = 0


for i in range(len(obsArchive)):
    if obsArchive.iloc[i][0] + oneDay > today:
        obsArchive['ageGroup'][i] = 'yesterday'
    elif obsArchive.iloc[i][0] + threeDays > today:
        obsArchive['ageGroup'][i] = '3 day'
    elif obsArchive.iloc[i][0] + oneWeek > today:
        obsArchive['ageGroup'][i] = 'week'
    else:
        obsArchive['ageGroup'][i] = 'old'


obsArchive
# Out:
#                    Date                                      Location  \
# 0   2020-12-13 04:04:00               Sunburst Meadows above Treeline
# 1   2020-12-13 02:00:00           Motorized Uptrack / Repeat Offender
# 126                            Elias Holt   60.788737 -149.179754      False
# 127                             Malcolm H   60.794430 -149.199667      False
# 128     Wagner / Johnston-Bloom Forecaster  60.817961 -149.198294      False
# 129                      George Creighton   60.995496 -149.093237      False
# 130                          Andy Moderow   60.785344 -149.164476       True
# 131                              Anonymous  61.216874 -149.467287      False
# 132                                   b s   61.766294 -149.305496      False
# 133                 Jed Workman Forecaster  61.782897 -149.268975       True
#
#     Collapsing Cracking  flagCount  \
# 0        False    False          0
# 1        False    False          0
# 2        False    False          0
# 3        False    False          0
# 4        False    False          0
# 5        False    False          0
# 6        False    False          0
# 7        False    False          0
# 8        False    False          0
# 9        False    False          0
# 10       False    False          0
# 11       False    False          0
# 12       False    False          0
# 13       False    False          0
# 14       False    False          0
# 15        True     True          2
# 16       False    False          1
# 17       False    False          0
# 18       False    False          0
# 19       False    False          0
# 20        True     True          2
# 21       False    False          1
# 22       False    False          0
# 23        True    False          1
# 24       False    False          0
# 25        True    False          1
# 26       False    False          1
# 27       False    False          0
# 28       False    False          0
# 29       False    False          1
# ..         ...      ...        ...
# 104       True     True          2
# 105      False    False          0
# 106       True     True          2
# 107      False    False          0
# 108      False    False          0
# 109      False     True          1
# 110      False    False          0
# 111      False    False          0
# 112       True    False          1
# 113      False    False          0
# 114      False    False          0
# 115      False    False          0
# 116      False    False          0
# 117      False    False          0
# 118      False    False          0
# 119      False    False          0
# 120       True    False          1
# 121       True    False          1
# 122       True    False          1
# 123       True    False          2
# 124      False    False          0
# 125      False    False          0
# 126       True    False          1
# 127      False     True          1
# 128       True     True          2
# 129       True    False          1
# 130       True    False          2
# 131      False    False          0
# 132      False    False          0
# 133       True     True          3
#
#                                                    url   ageGroup
# 0    https://www.cnfaic.org/observations/sunburst-m...  yesterday
# 1    https://www.cnfaic.org/observations/motorized-...  yesterday
# 2      https://www.cnfaic.org/observations/eddies-111/      3 day
# 3    https://www.cnfaic.org/observations/raggedtop-17/      3 day
# 4    https://www.cnfaic.org/observations/iditarod-t...      3 day
# 5    https://www.cnfaic.org/observations/carter-cre...       week
# 6    https://www.cnfaic.org/observations/notch-moun...       week
# 7     https://www.cnfaic.org/observations/manitoba-71/       week
# 8    https://www.cnfaic.org/observations/tincan-alp...       week
# 9    https://www.cnfaic.org/observations/valley-of-...       week
# 10   https://www.cnfaic.org/observations/lynx-creek...       week
# 11   https://www.cnfaic.org/observations/se-summit-...       week
# 12   https://www.cnfaic.org/observations/south-summ...       week
# 13   https://www.cnfaic.org/observations/sunburst-235/       week
# 14   https://www.cnfaic.org/observations/cornbiscui...       week
# 15   https://www.cnfaic.org/observations/pinnacle-b...       week
# 16   https://www.cnfaic.org/observations/sunburst-234/       week
# 17   https://www.cnfaic.org/observations/lost-lake-...       week
# 18   https://www.cnfaic.org/observations/tenderfoot...       week
# 19   https://www.cnfaic.org/observations/seattle-ri...       week
# 20     https://www.cnfaic.org/observations/tincan-295/        old
# 21   https://www.cnfaic.org/observations/tincan-tre...        old
# 22   https://www.cnfaic.org/observations/notch-moun...        old
# 23   https://www.cnfaic.org/observations/tincan-tre...        old
# 24   https://www.cnfaic.org/observations/south-fork...        old
# 25   https://www.cnfaic.org/observations/cornbiscui...        old
# 26   https://www.cnfaic.org/observations/cornbiscui...        old
# 27    https://www.cnfaic.org/observations/silvertip-8/        old
# 28   https://www.cnfaic.org/observations/carter-lak...        old
# 29   https://www.cnfaic.org/observations/eddies-abo...        old
# ..                                                 ...        ...
# 104  https://www.cnfaic.org/observations/west-face-...        old
# 105  https://www.cnfaic.org/observations/tincan-tre...        old
# 106  https://www.cnfaic.org/observations/sunburst-a...        old
# 107  https://www.cnfaic.org/observations/tincan-sea...        old
# 108  https://www.cnfaic.org/observations/tincan-tre...        old
# 109     https://www.cnfaic.org/observations/peak-3-13/        old
# 110    https://www.cnfaic.org/observations/eddies-105/        old
# 111  https://www.cnfaic.org/observations/good-hope-...        old
# 112  https://www.cnfaic.org/observations/base-of-ed...        old
# 113  https://www.cnfaic.org/observations/sunburst-227/        old
# 114  https://www.cnfaic.org/observations/johns-cr-s...        old
# 115  https://www.cnfaic.org/observations/government...        old
# 116      https://www.cnfaic.org/observations/mabitoba/        old
# 117  https://www.cnfaic.org/observations/peak-conne...        old
# 118  https://www.cnfaic.org/observations/marmot-mou...        old
# 119  https://www.cnfaic.org/observations/rabbit-cre...        old
# 120    https://www.cnfaic.org/observations/tincan-289/        old
# 121    https://www.cnfaic.org/observations/eddies-104/        old
# 122  https://www.cnfaic.org/observations/seattle-ri...        old
# 123  https://www.cnfaic.org/observations/silvertip-...        old
# 124  https://www.cnfaic.org/observations/microdot-s...        old
# 125  https://www.cnfaic.org/observations/tincan-abo...        old
# 126    https://www.cnfaic.org/observations/tincan-288/        old
# 127  https://www.cnfaic.org/observations/tincan-com...        old
# 128  https://www.cnfaic.org/observations/seattle-ri...        old
# 129  https://www.cnfaic.org/observations/girdwood-v...        old
# 130    https://www.cnfaic.org/observations/tincan-287/        old
# 131  https://www.cnfaic.org/observations/hiland-fro...        old
# 132  https://www.cnfaic.org/observations/hatch-peak...        old
# 133  https://www.cnfaic.org/observations/marmot-tes...        old
#
# [134 rows x 11 columns]

# %%
dfYes = obsArchive[obsArchive['ageGroup'].isin(['yesterday'])]
df3day = obsArchive[obsArchive['ageGroup'].isin(['3 day'])]
dfWeek = obsArchive[obsArchive['ageGroup'].isin(['week'])]

# %%
fgObs = folium.FeatureGroup(name = 'Observations')
m.add_child(fgObs)
gYes = folium.plugins.FeatureGroupSubGroup(fgObs, 'Yesterday')
g3day = folium.plugins.FeatureGroupSubGroup(fgObs, '3 Days')
gWeek = folium.plugins.FeatureGroupSubGroup(fgObs, 'One Week')
subGroups = [gYes, g3day, gWeek]


frames = [dfYes, df3day, dfWeek]
colors = ['red', 'green', 'blue']
resolution, width, height = (72, 40, 40)

#iterate through the three time frames:
for i in range(len(frames)):
    m.add_child(subGroups[i])
    
    #iterate through the obs:
    for j in range(len(frames[i])):
        if str(frames[i].iloc[j][3]) != 'nan':  #only handle observations with coordinates
            filename = 'flag (' + str(int(frames[i].iloc[j][[8]])) + ').jpg' #load correct flag image
            encoded = base64.b64encode(open(filename, 'rb').read())
            image='<img src="data:image/jpeg;base64,{}">'.format 
            #add marker to subgroup
            subGroups[i].add_child(
                folium.Marker([frames[i].iloc[j][3],
                frames[i].iloc[j][4]], 
                popup = (frames[i].iloc[j][1].encode('1252')).decode('utf-8') + ' ' +
                '<br>' + frames[i].iloc[j][2] +
                '<a href="{}" target="_blank">Link</a>'.format(frames[i].iloc[j][9]) +
                image(encoded.decode('UTF-8')),
                icon = folium.Icon(color = colors[i])))

folium.LayerControl().add_to(m)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-39-9611d7d34ea1> in <module>
#      27                 popup = (frames[i].iloc[j][1].encode('1252')).decode('utf-8') + ' ' +
#      28                 '<br>' + frames[i].iloc[j][2] +
# ---> 29                 '<a href="{}" target="_blank">Link</a>'.format(frames[i].iloc[j][9]) +
#      30                 image(encoded.decode('UTF-8')),
#      31                 icon = folium.Icon(color = colors[i])))
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 5: invalid start byte

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Working Zone

# %%
#Better Pop-ups
#Create new map to practice popups on:
# Load USGS
url_base = 'http://server.arcgisonline.com/ArcGIS/rest/services/'
service = 'NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
tileset = url_base + service

# Create the map
testMap = folium.Map(location = [60.79443,-149.199667], zoom_start = 11, tiles = tileset,
               attr='USGS Style')
i = 0
testFG = folium.FeatureGroup('popup test')
#Select images for the pop-up:
Filename ='flag (' + str(int(obsArchive.iloc[0][[8]])) + ').jpg'
encoded = base64.b64encode(open(Filename, 'rb').read())
image='<img src="data:image/jpeg;base64,{}">'.format 
#resolution, width, height = 72, 40, 40
"""iframe = IFrame(html(encoded.decode('UTF-8')), width=(width)+10, 
                height=(height)+10)
popup = folium.Popup(iframe, max_width=1000)
icon = folium.Icon(color="red", icon="ok")
marker = folium.Marker(location=[60.794430,	-149.199667], popup=popup, icon=icon)
marker.add_to(testMap)"""


testMap.add_child(folium.Marker([obsArchive.iloc[0][3],obsArchive.iloc[0][4]], 
                                popup = '<style> h1 {white-space: nowrap; font-size: 120%;}</style> <h1>' +
                                '<a href="%s" target="_blank">%s</a>' % (frames[0].iloc[0][9], obsArchive.iloc[0][1]) +
                                '</h1>' +
                                frames[0].iloc[0][2] + '<br>'+
                                frames[0].iloc[0][0].strftime("%m/%d/%y %H:%M",) +
                                image(encoded.decode('UTF-8')) ,
                                icon = folium.Icon(color = colors[i])))

testMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Filename ='flag (' + str(obsArchive.iloc[0][[8]]) + ').jpg'
encoded = base64.b64encode(open(Filename, 'rb').read())
html='<img src="data:image/jpeg;base64,{}">'.format 
resolution, width, height = 72, 40, 40
iframe = IFrame(html(encoded.decode('UTF-8')), width=(width)+10, 
                height=(height)+10)
popup = folium.Popup(iframe, max_width=1000)
icon = folium.Icon(color="red", icon="ok")
marker = folium.Marker(location=[60.794430,	-149.199667], popup=popup, icon=icon)
marker.add_to(testMap)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-4eca474910df> in <module>
#       1 Filename ='flag (' + str(obsArchive.iloc[0][[8]]) + ').jpg'
# ----> 2 encoded = base64.b64encode(open(Filename, 'rb').read())
#       3 html='<img src="data:image/jpeg;base64,{}">'.format
#       4 resolution, width, height = 72, 40, 40
#       5 iframe = IFrame(html(encoded.decode('UTF-8')), width=(width)+10,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'flag (flagCount    0\nName: 0, dtype: object).jpg'

# %%
m.save('map.html')
